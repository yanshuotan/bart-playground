# %%
import numpy as np
import sys
from pyinstrument import Profiler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import os
sys.path.append(os.path.dirname(os.getcwd()))
from bart_playground import *

import bartz

# %%
proposal_probs = {"grow" : 0.5,
                  "prune" : 0.5}
generator = DataGenerator(n_samples=160, n_features=2, noise=0.1, random_seed=42)
X, y = generator.generate(scenario="piecewise_flat")
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
np.set_printoptions(suppress=True)
print(y_train[:12])
# Out:
# [ 0.50327821  0.60672224  0.26898966  0.55211673  0.50693811  0.66162097
#  -0.64127659  0.65112284  0.03487759  0.23276531  0.44055996  0.38216964]

# %%
dgen = DataGenerator(n_samples=100, n_features=3, noise=0.1, random_seed=42)
X, y = dgen.generate(scenario="linear")
data = Dataset(X, y, X)

rng = np.random.default_rng()

# %%
rng = np.random.default_rng(316)
rng.choice(np.arange(0, 201),size=2)
# Out:
# array([  1, 200])

# %%
processor = DefaultPreprocessor(max_bins=100)

# %%
prior = NTreePrior(n_trees=100,generator=rng)

# %%
sampler = NtreeSampler(prior,proposal_probs=proposal_probs,generator=rng)
#data = processor.fit_transform(X_train,y_train)
sampler.add_data(data)
sampler.run(100)
# Out:
# Running iteration 0
# <bart_playground.moves.Combine object at 0x00000181087CA920>
# <bart_playground.moves.Break object at 0x0000018105F06CE0>
# <bart_playground.moves.Combine object at 0x0000018105F98790>
# <bart_playground.moves.Break object at 0x0000018105F06CE0>
# <bart_playground.moves.Combine object at 0x000001810A5DAD10>
# <bart_playground.moves.Combine object at 0x0000018105F06CE0>
# <bart_playground.moves.Break object at 0x000001810A5DAD10>
# <bart_playground.moves.Break object at 0x000001810A5DAD10>
# <bart_playground.moves.Combine object at 0x000001810A648760>
# <bart_playground.moves.Break object at 0x000001810A6B7280>
# Running iteration 10
# <bart_playground.moves.Combine object at 0x000001810A6B7490>
# <bart_playground.moves.Combine object at 0x000001810A6B7D60>
# <bart_playground.moves.Break object at 0x000001810A6B7E80>
# <bart_playground.moves.Break object at 0x000001810B1C1A50>
# <bart_playground.moves.Combine object at 0x000001810B1C2DD0>
# <bart_playground.moves.Break object at 0x000001810B1C2DD0>
# <bart_playground.moves.Break object at 0x000001810B21A3E0>
# <bart_playground.moves.Combine object at 0x000001810B21B400>
# <bart_playground.moves.Combine object at 0x000001810B21BE20>
# <bart_playground.moves.Break object at 0x000001810B21BE20>
# Running iteration 20
# <bart_playground.moves.Break object at 0x000001810B26DC00>
# <bart_playground.moves.Break object at 0x000001810B26DC00>
# <bart_playground.moves.Break object at 0x000001810B26DC00>
# <bart_playground.moves.Break object at 0x000001810B2C3E50>
# <bart_playground.moves.Combine object at 0x000001810B2C3160>
# <bart_playground.moves.Break object at 0x000001810B2C3160>
# <bart_playground.moves.Combine object at 0x000001810B31F940>
# <bart_playground.moves.Combine object at 0x000001810B2C3160>
# <bart_playground.moves.Combine object at 0x000001810B31F970>
# <bart_playground.moves.Break object at 0x000001810B36B0D0>
# Running iteration 30
# <bart_playground.moves.Combine object at 0x000001810B3697E0>
# <bart_playground.moves.Break object at 0x000001810B36AB90>
# <bart_playground.moves.Combine object at 0x000001810C391A80>
# <bart_playground.moves.Combine object at 0x000001810C392E90>
# <bart_playground.moves.Break object at 0x000001810C393520>
# <bart_playground.moves.Combine object at 0x000001810C393520>
# <bart_playground.moves.Break object at 0x000001810C3E3A00>
# <bart_playground.moves.Combine object at 0x000001810C3E1450>
# <bart_playground.moves.Combine object at 0x000001810C393520>
# <bart_playground.moves.Combine object at 0x000001810C43F250>
# Running iteration 40
# <bart_playground.moves.Break object at 0x000001810C43F820>
# <bart_playground.moves.Combine object at 0x000001810C43DC60>
# <bart_playground.moves.Combine object at 0x000001810C43F250>
# <bart_playground.moves.Combine object at 0x000001810C493EE0>
# <bart_playground.moves.Combine object at 0x000001810C4931C0>
# <bart_playground.moves.Break object at 0x000001810C493EE0>
# <bart_playground.moves.Break object at 0x000001810C4EF790>
# <bart_playground.moves.Combine object at 0x000001810C4EE1D0>
# <bart_playground.moves.Break object at 0x000001810C4EE380>
# <bart_playground.moves.Break object at 0x000001810C4EE1D0>
# Running iteration 50
# <bart_playground.moves.Combine object at 0x000001810C541ED0>
# <bart_playground.moves.Break object at 0x000001810C541A80>
# <bart_playground.moves.Combine object at 0x000001810C541A80>
# <bart_playground.moves.Combine object at 0x000001810C58F8E0>
# <bart_playground.moves.Break object at 0x000001810C541A80>
# <bart_playground.moves.Break object at 0x000001810C58D1E0>
# <bart_playground.moves.Combine object at 0x000001810C541A80>
# <bart_playground.moves.Combine object at 0x000001810C5EBA60>
# <bart_playground.moves.Combine object at 0x000001810C5EAE90>
# <bart_playground.moves.Break object at 0x000001810C5EBA60>
# Running iteration 60
# <bart_playground.moves.Combine object at 0x000001810C63D600>
# <bart_playground.moves.Combine object at 0x000001810C63DA50>
# <bart_playground.moves.Break object at 0x000001810C63DA50>
# <bart_playground.moves.Combine object at 0x000001810C69AC20>
# <bart_playground.moves.Combine object at 0x000001810C69AF80>
# <bart_playground.moves.Combine object at 0x000001810C699E40>
# <bart_playground.moves.Break object at 0x000001810C69B910>
# <bart_playground.moves.Break object at 0x000001810C6EFB80>
# <bart_playground.moves.Combine object at 0x000001810C69B910>
# <bart_playground.moves.Break object at 0x000001810C6EEE00>
# Running iteration 70
# <bart_playground.moves.Combine object at 0x000001810C748B20>
# <bart_playground.moves.Break object at 0x000001810C74AE90>
# <bart_playground.moves.Combine object at 0x000001810C74AE90>
# <bart_playground.moves.Break object at 0x000001810C74AE90>
# <bart_playground.moves.Break object at 0x000001810C79B790>
# <bart_playground.moves.Combine object at 0x000001810C79A470>
# <bart_playground.moves.Combine object at 0x000001810C79A470>
# <bart_playground.moves.Break object at 0x000001810C74BBE0>
# <bart_playground.moves.Break object at 0x000001810C7F7E50>
# <bart_playground.moves.Break object at 0x000001810C7F7EE0>
# Running iteration 80
# <bart_playground.moves.Break object at 0x000001810C7F7EE0>
# <bart_playground.moves.Combine object at 0x000001810C84BB20>
# <bart_playground.moves.Break object at 0x000001810C7F7EE0>
# <bart_playground.moves.Combine object at 0x000001810C84A740>
# <bart_playground.moves.Break object at 0x000001810C84A050>
# <bart_playground.moves.Combine object at 0x000001810C8ABEB0>
# <bart_playground.moves.Combine object at 0x000001810C8AA410>
# <bart_playground.moves.Break object at 0x000001810C8ABEB0>
# <bart_playground.moves.Break object at 0x000001810C8FB5B0>
# <bart_playground.moves.Combine object at 0x000001810C8F94E0>
# Running iteration 90
# <bart_playground.moves.Break object at 0x000001810C8AACE0>
# <bart_playground.moves.Break object at 0x000001810C95BFD0>
# <bart_playground.moves.Combine object at 0x000001810C8AACE0>
# <bart_playground.moves.Combine object at 0x0000018105F9AC50>
# <bart_playground.moves.Break object at 0x0000018105F42830>
# <bart_playground.moves.Break object at 0x000001810D983850>
# <bart_playground.moves.Combine object at 0x0000018105F42830>
# <bart_playground.moves.Break object at 0x000001810D983580>
# <bart_playground.moves.Combine object at 0x000001810D9E3D60>
# <bart_playground.moves.Break object at 0x000001810D9E15A0>
# [<bart_playground.params.Parameters at 0x18105f98b20>,
#  <bart_playground.params.Parameters at 0x1810a648a90>,
#  <bart_playground.params.Parameters at 0x1810a648ca0>,
#  <bart_playground.params.Parameters at 0x1810a64a6b0>,
#  <bart_playground.params.Parameters at 0x1810a64b6a0>,
#  <bart_playground.params.Parameters at 0x1810a6b46d0>,
#  <bart_playground.params.Parameters at 0x1810a6b5c30>,
#  <bart_playground.params.Parameters at 0x1810a6b7130>,
#  <bart_playground.params.Parameters at 0x1810b1c02e0>,
#  <bart_playground.params.Parameters at 0x1810b1c15d0>,
#  <bart_playground.params.Parameters at 0x1810b1c2890>,
#  <bart_playground.params.Parameters at 0x1810b1c3a00>,
#  <bart_playground.params.Parameters at 0x1810b218970>,
#  <bart_playground.params.Parameters at 0x1810b21a050>,
#  <bart_playground.params.Parameters at 0x1810b21b6d0>,
#  <bart_playground.params.Parameters at 0x1810b26cd90>,
#  <bart_playground.params.Parameters at 0x1810b26dba0>,
#  <bart_playground.params.Parameters at 0x1810b26f460>,
#  <bart_playground.params.Parameters at 0x1810b2c0160>,
#  <bart_playground.params.Parameters at 0x1810b2c1360>,
#  <bart_playground.params.Parameters at 0x1810b2c26b0>,
#  <bart_playground.params.Parameters at 0x1810b2c38e0>,
#  <bart_playground.params.Parameters at 0x1810b31d270>,
#  <bart_playground.params.Parameters at 0x1810b31d990>,
#  <bart_playground.params.Parameters at 0x1810b31f5b0>,
#  <bart_playground.params.Parameters at 0x1810b368a90>,
#  <bart_playground.params.Parameters at 0x1810b369f00>,
#  <bart_playground.params.Parameters at 0x1810b36b4f0>,
#  <bart_playground.params.Parameters at 0x1810c390070>,
#  <bart_playground.params.Parameters at 0x1810c391ab0>,
#  <bart_playground.params.Parameters at 0x1810c392ce0>,
#  <bart_playground.params.Parameters at 0x1810c393d00>,
#  <bart_playground.params.Parameters at 0x1810c3e10f0>,
#  <bart_playground.params.Parameters at 0x1810c3e25f0>,
#  <bart_playground.params.Parameters at 0x1810c3e35b0>,
#  <bart_playground.params.Parameters at 0x1810c43cbb0>,
#  <bart_playground.params.Parameters at 0x1810c43e3b0>,
#  <bart_playground.params.Parameters at 0x1810c43f640>,
#  <bart_playground.params.Parameters at 0x1810c490610>,
#  <bart_playground.params.Parameters at 0x1810c491810>,
#  <bart_playground.params.Parameters at 0x1810c492860>,
#  <bart_playground.params.Parameters at 0x1810c493be0>,
#  <bart_playground.params.Parameters at 0x1810c4ecca0>,
#  <bart_playground.params.Parameters at 0x1810c4ee620>,
#  <bart_playground.params.Parameters at 0x1810c4ef8b0>,
#  <bart_playground.params.Parameters at 0x1810c5409a0>,
#  <bart_playground.params.Parameters at 0x1810c541ba0>,
#  <bart_playground.params.Parameters at 0x1810c542920>,
#  <bart_playground.params.Parameters at 0x1810c58c310>,
#  <bart_playground.params.Parameters at 0x1810c58d630>,
#  <bart_playground.params.Parameters at 0x1810c58e4a0>,
#  <bart_playground.params.Parameters at 0x1810c58f640>,
#  <bart_playground.params.Parameters at 0x1810c5e86d0>,
#  <bart_playground.params.Parameters at 0x1810c5e9ed0>,
#  <bart_playground.params.Parameters at 0x1810c5eb1f0>,
#  <bart_playground.params.Parameters at 0x1810c63c370>,
#  <bart_playground.params.Parameters at 0x1810c63d900>,
#  <bart_playground.params.Parameters at 0x1810c63e7a0>,
#  <bart_playground.params.Parameters at 0x1810c63fd30>,
#  <bart_playground.params.Parameters at 0x1810c698dc0>,
#  <bart_playground.params.Parameters at 0x1810c69a260>,
#  <bart_playground.params.Parameters at 0x1810c69b400>,
#  <bart_playground.params.Parameters at 0x1810c69bfa0>,
#  <bart_playground.params.Parameters at 0x1810c6ed2a0>,
#  <bart_playground.params.Parameters at 0x1810c6ee5f0>,
#  <bart_playground.params.Parameters at 0x1810c6efa30>,
#  <bart_playground.params.Parameters at 0x1810c748c40>,
#  <bart_playground.params.Parameters at 0x1810c74a170>,
#  <bart_playground.params.Parameters at 0x1810c74b250>,
#  <bart_playground.params.Parameters at 0x1810c798070>,
#  <bart_playground.params.Parameters at 0x1810c7992d0>,
#  <bart_playground.params.Parameters at 0x1810c79a7a0>,
#  <bart_playground.params.Parameters at 0x1810c79bb50>,
#  <bart_playground.params.Parameters at 0x1810c7f4c70>,
#  <bart_playground.params.Parameters at 0x1810c7f5c90>,
#  <bart_playground.params.Parameters at 0x1810c7f6d70>,
#  <bart_playground.params.Parameters at 0x1810c8482b0>,
#  <bart_playground.params.Parameters at 0x1810c849180>,
#  <bart_playground.params.Parameters at 0x1810c84a5c0>,
#  <bart_playground.params.Parameters at 0x1810c84bac0>,
#  <bart_playground.params.Parameters at 0x1810c8a8880>,
#  <bart_playground.params.Parameters at 0x1810c8a9f30>,
#  <bart_playground.params.Parameters at 0x1810c7f7f40>,
#  <bart_playground.params.Parameters at 0x1810c8f8880>,
#  <bart_playground.params.Parameters at 0x1810c8f9210>,
#  <bart_playground.params.Parameters at 0x1810c8fa3e0>,
#  <bart_playground.params.Parameters at 0x1810c8fbc10>,
#  <bart_playground.params.Parameters at 0x1810c9591b0>,
#  <bart_playground.params.Parameters at 0x1810c95a0b0>,
#  <bart_playground.params.Parameters at 0x1810c95b340>,
#  <bart_playground.params.Parameters at 0x1810d980640>,
#  <bart_playground.params.Parameters at 0x1810d981570>,
#  <bart_playground.params.Parameters at 0x1810d9825c0>,
#  <bart_playground.params.Parameters at 0x1810d9837f0>,
#  <bart_playground.params.Parameters at 0x1810d9e1000>,
#  <bart_playground.params.Parameters at 0x1810d9e2140>,
#  <bart_playground.params.Parameters at 0x1810d9e2fb0>,
#  <bart_playground.params.Parameters at 0x1810da34910>,
#  <bart_playground.params.Parameters at 0x1810da35660>,
#  <bart_playground.params.Parameters at 0x1810da36bf0>,
#  <bart_playground.params.Parameters at 0x1810da8c190>]

# %%
bart = ChangeNumTreeBART(ndpost=300, nskip=100, n_trees=100, proposal_probs=proposal_probs)
bart.fit(X_train, y_train)
# Out:
# Running iteration 0
# <bart_playground.moves.Break object at 0x000001810DA37E20>
# <bart_playground.moves.Combine object at 0x000001810DA37EE0>
# <bart_playground.moves.Combine object at 0x000001810DA37C70>
# <bart_playground.moves.Combine object at 0x000001810DA37E20>
# <bart_playground.moves.Combine object at 0x000001810DA37E20>
# <bart_playground.moves.Break object at 0x000001810DA8E650>
# <bart_playground.moves.Break object at 0x000001810DA37E20>
# <bart_playground.moves.Break object at 0x000001810DA8EFE0>
# <bart_playground.moves.Break object at 0x000001810DAE47F0>
# <bart_playground.moves.Break object at 0x000001810DAE73D0>
# Running iteration 10
# <bart_playground.moves.Break object at 0x000001810DAE73D0>
# <bart_playground.moves.Combine object at 0x000001810DB33940>
# <bart_playground.moves.Break object at 0x000001810DB33580>
# <bart_playground.moves.Combine object at 0x000001810DB333A0>
# <bart_playground.moves.Combine object at 0x000001810DB33850>
# <bart_playground.moves.Combine object at 0x000001810DFCD720>
# <bart_playground.moves.Break object at 0x000001810DFCFF70>
# <bart_playground.moves.Combine object at 0x000001810DFCD720>
# <bart_playground.moves.Combine object at 0x000001810E01F160>
# <bart_playground.moves.Combine object at 0x000001810DFCD720>
# Running iteration 20
# <bart_playground.moves.Combine object at 0x000001810DFCD720>
# <bart_playground.moves.Break object at 0x000001810E0678B0>
# <bart_playground.moves.Combine object at 0x000001810DFCD720>
# <bart_playground.moves.Break object at 0x000001810DFCD720>
# <bart_playground.moves.Combine object at 0x000001810E0C6D70>
# <bart_playground.moves.Combine object at 0x000001810E0C62C0>
# <bart_playground.moves.Break object at 0x000001810E0C7550>
# <bart_playground.moves.Combine object at 0x000001810E0C7550>
# <bart_playground.moves.Break object at 0x000001810E117940>
# <bart_playground.moves.Combine object at 0x000001810E0C7550>
# Running iteration 30
# <bart_playground.moves.Break object at 0x000001810E116AD0>
# <bart_playground.moves.Break object at 0x000001810E172FE0>
# <bart_playground.moves.Break object at 0x000001810E116AD0>
# <bart_playground.moves.Combine object at 0x000001810E170F10>
# <bart_playground.moves.Combine object at 0x000001810E172020>
# <bart_playground.moves.Combine object at 0x000001810E1BBD30>
# <bart_playground.moves.Combine object at 0x000001810E172020>
# <bart_playground.moves.Break object at 0x000001810E1BB6D0>
# <bart_playground.moves.Break object at 0x000001810E172020>
# <bart_playground.moves.Break object at 0x000001810E1BB6D0>
# Running iteration 40
# <bart_playground.moves.Combine object at 0x000001810E21B0D0>
# <bart_playground.moves.Break object at 0x000001810E267E50>
# <bart_playground.moves.Break object at 0x000001810E267F40>
# <bart_playground.moves.Break object at 0x000001810E264C40>
# <bart_playground.moves.Combine object at 0x000001810E264C40>
# <bart_playground.moves.Break object at 0x000001810E264C40>
# <bart_playground.moves.Combine object at 0x000001810E2BAF50>
# <bart_playground.moves.Break object at 0x000001810E2BB6A0>
# <bart_playground.moves.Combine object at 0x000001810E316DA0>
# <bart_playground.moves.Break object at 0x000001810E315F90>
# Running iteration 50
# <bart_playground.moves.Combine object at 0x000001810E315F90>
# <bart_playground.moves.Combine object at 0x000001810E315F90>
# <bart_playground.moves.Combine object at 0x000001810E315F90>
# <bart_playground.moves.Combine object at 0x000001810E3673D0>
# <bart_playground.moves.Combine object at 0x000001810E366200>
# <bart_playground.moves.Combine object at 0x000001810E3C7FD0>
# <bart_playground.moves.Combine object at 0x000001810E3C6D40>
# <bart_playground.moves.Break object at 0x000001810E3C5090>
# <bart_playground.moves.Break object at 0x000001810E3C5090>
# <bart_playground.moves.Break object at 0x000001810E3C5090>
# Running iteration 60
# <bart_playground.moves.Break object at 0x000001810E4160E0>
# <bart_playground.moves.Break object at 0x000001810E4164A0>
# <bart_playground.moves.Break object at 0x000001810E4164A0>
# <bart_playground.moves.Break object at 0x000001810E46BD30>
# <bart_playground.moves.Combine object at 0x000001810E46B1C0>
# <bart_playground.moves.Combine object at 0x000001810E469960>
# <bart_playground.moves.Combine object at 0x000001810E469960>
# <bart_playground.moves.Break object at 0x000001810F498A90>
# <bart_playground.moves.Combine object at 0x000001810F49B790>
# <bart_playground.moves.Combine object at 0x000001810F49B790>
# Running iteration 70
# <bart_playground.moves.Break object at 0x000001810F4E7A00>
# <bart_playground.moves.Combine object at 0x000001810F49B790>
# <bart_playground.moves.Break object at 0x000001810F49B790>
# <bart_playground.moves.Combine object at 0x000001810F54BFD0>
# <bart_playground.moves.Combine object at 0x000001810F49B790>
# <bart_playground.moves.Combine object at 0x000001810F54AE30>
# <bart_playground.moves.Break object at 0x000001810F54AE30>
# <bart_playground.moves.Combine object at 0x000001810F59F220>
# <bart_playground.moves.Combine object at 0x000001810F59ED10>
# <bart_playground.moves.Combine object at 0x000001810F59F2E0>
# Running iteration 80
# <bart_playground.moves.Combine object at 0x000001810F59F430>
# <bart_playground.moves.Combine object at 0x000001810F5F76A0>
# <bart_playground.moves.Combine object at 0x000001810F59FA60>
# <bart_playground.moves.Break object at 0x000001810F5F4D30>
# <bart_playground.moves.Combine object at 0x000001810F5F78B0>
# <bart_playground.moves.Break object at 0x000001810F653490>
# <bart_playground.moves.Break object at 0x000001810F651960>
# <bart_playground.moves.Combine object at 0x000001810F651960>
# <bart_playground.moves.Combine object at 0x000001810F651960>
# <bart_playground.moves.Combine object at 0x000001810F6A73D0>
# Running iteration 90
# <bart_playground.moves.Break object at 0x000001810F6A5DE0>
# <bart_playground.moves.Break object at 0x000001810F6A7D30>
# <bart_playground.moves.Combine object at 0x000001810F6A7D30>
# <bart_playground.moves.Break object at 0x000001810F6FF580>
# <bart_playground.moves.Combine object at 0x000001810F6FFB80>
# <bart_playground.moves.Break object at 0x000001810F6FDA50>
# <bart_playground.moves.Break object at 0x000001810F6FDA50>
# <bart_playground.moves.Break object at 0x000001810F753820>
# <bart_playground.moves.Combine object at 0x000001810F752080>
# <bart_playground.moves.Combine object at 0x000001810F753820>
# Running iteration 100
# <bart_playground.moves.Combine object at 0x000001810F753820>
# <bart_playground.moves.Break object at 0x000001810F753820>
# <bart_playground.moves.Combine object at 0x000001810F7AD870>
# <bart_playground.moves.Combine object at 0x000001810F7AD870>
# <bart_playground.moves.Break object at 0x000001810F7AD870>
# <bart_playground.moves.Break object at 0x000001810F80F310>
# <bart_playground.moves.Break object at 0x000001810F80EA40>
# <bart_playground.moves.Combine object at 0x000001810F80D570>
# <bart_playground.moves.Break object at 0x000001810F80D570>
# <bart_playground.moves.Break object at 0x000001810F80D570>
# Running iteration 110
# <bart_playground.moves.Break object at 0x000001810F865D50>
# <bart_playground.moves.Combine object at 0x000001810F866F80>
# <bart_playground.moves.Combine object at 0x000001810F865D50>
# <bart_playground.moves.Break object at 0x000001810F866F80>
# <bart_playground.moves.Combine object at 0x000001810F8C5660>
# <bart_playground.moves.Combine object at 0x000001810F8C76A0>
# <bart_playground.moves.Combine object at 0x000001810F8C76A0>
# <bart_playground.moves.Break object at 0x000001810F923670>
# <bart_playground.moves.Break object at 0x000001810F8C76A0>
# <bart_playground.moves.Break object at 0x000001810F923AF0>
# Running iteration 120
# <bart_playground.moves.Break object at 0x000001810F923670>
# <bart_playground.moves.Break object at 0x0000018110951B40>
# <bart_playground.moves.Combine object at 0x0000018110952710>
# <bart_playground.moves.Break object at 0x0000018110953C70>
# <bart_playground.moves.Break object at 0x0000018110953C70>
# <bart_playground.moves.Combine object at 0x00000181109AFCD0>
# <bart_playground.moves.Break object at 0x00000181109AD210>
# <bart_playground.moves.Break object at 0x00000181109AF940>
# <bart_playground.moves.Combine object at 0x00000181109AF940>
# <bart_playground.moves.Break object at 0x0000018110A0F580>
# Running iteration 130
# <bart_playground.moves.Combine object at 0x0000018110A0E320>
# <bart_playground.moves.Combine object at 0x0000018110A0EF80>
# <bart_playground.moves.Combine object at 0x0000018110A0E320>
# <bart_playground.moves.Combine object at 0x0000018110A73B80>
# <bart_playground.moves.Break object at 0x0000018110A0E320>
# <bart_playground.moves.Break object at 0x0000018110A72D40>
# <bart_playground.moves.Break object at 0x0000018110A0E320>
# <bart_playground.moves.Break object at 0x0000018110ACB010>
# <bart_playground.moves.Break object at 0x0000018110A0E320>
# <bart_playground.moves.Break object at 0x0000018110A0E320>
# Running iteration 140
# <bart_playground.moves.Combine object at 0x0000018110B2FF40>
# <bart_playground.moves.Break object at 0x0000018110B2DB70>
# <bart_playground.moves.Break object at 0x0000018110B2F9A0>
# <bart_playground.moves.Combine object at 0x0000018111023670>
# <bart_playground.moves.Break object at 0x0000018110B2DFC0>
# <bart_playground.moves.Combine object at 0x0000018111022320>
# <bart_playground.moves.Break object at 0x0000018111022E00>
# <bart_playground.moves.Combine object at 0x0000018111022E00>
# <bart_playground.moves.Break object at 0x000001811108FC10>
# <bart_playground.moves.Break object at 0x0000018111022E00>
# Running iteration 150
# <bart_playground.moves.Combine object at 0x000001811108FC10>
# <bart_playground.moves.Combine object at 0x00000181111052A0>
# <bart_playground.moves.Break object at 0x000001811108FC10>
# <bart_playground.moves.Break object at 0x00000181111069E0>
# <bart_playground.moves.Combine object at 0x000001811108FC10>
# <bart_playground.moves.Combine object at 0x00000181111069E0>
# <bart_playground.moves.Break object at 0x0000018111167670>
# <bart_playground.moves.Combine object at 0x00000181111069E0>
# <bart_playground.moves.Break object at 0x0000018111165C60>
# <bart_playground.moves.Break object at 0x00000181111D7C10>
# Running iteration 160
# <bart_playground.moves.Break object at 0x0000018111165C60>
# <bart_playground.moves.Combine object at 0x0000018111165C60>
# <bart_playground.moves.Break object at 0x0000018111165C60>
# <bart_playground.moves.Combine object at 0x000001811123D4E0>
# <bart_playground.moves.Combine object at 0x0000018111165C60>
# <bart_playground.moves.Combine object at 0x000001811123ED40>
# <bart_playground.moves.Break object at 0x0000018111165C60>
# <bart_playground.moves.Break object at 0x00000181112B7310>
# <bart_playground.moves.Combine object at 0x00000181112B7310>
# <bart_playground.moves.Combine object at 0x00000181112B7310>
# Running iteration 170
# <bart_playground.moves.Combine object at 0x0000018112302C80>
# <bart_playground.moves.Break object at 0x0000018112302B30>
# <bart_playground.moves.Break object at 0x0000018112302B30>
# <bart_playground.moves.Break object at 0x000001811235F1F0>
# <bart_playground.moves.Break object at 0x000001811235E890>
# <bart_playground.moves.Break object at 0x000001811235F5E0>
# <bart_playground.moves.Combine object at 0x000001811235E890>
# <bart_playground.moves.Break object at 0x00000181123DBA60>
# <bart_playground.moves.Break object at 0x00000181123DA620>
# <bart_playground.moves.Break object at 0x000001811244EBC0>
# Running iteration 180
# <bart_playground.moves.Break object at 0x00000181123DBBB0>
# <bart_playground.moves.Combine object at 0x000001811244FDF0>
# <bart_playground.moves.Combine object at 0x00000181123DBBB0>
# <bart_playground.moves.Combine object at 0x000001811244CA60>
# <bart_playground.moves.Break object at 0x000001811244CA60>
# <bart_playground.moves.Combine object at 0x00000181124B77C0>
# <bart_playground.moves.Combine object at 0x00000181124B6590>
# <bart_playground.moves.Combine object at 0x00000181124B6590>
# <bart_playground.moves.Break object at 0x0000018112535930>
# <bart_playground.moves.Combine object at 0x0000018112534C70>
# Running iteration 190
# <bart_playground.moves.Combine object at 0x0000018112535930>
# <bart_playground.moves.Combine object at 0x00000181125A7160>
# <bart_playground.moves.Combine object at 0x0000018112535930>
# <bart_playground.moves.Combine object at 0x00000181125A6FE0>
# <bart_playground.moves.Break object at 0x00000181125A72B0>
# <bart_playground.moves.Combine object at 0x000001811262B9A0>
# <bart_playground.moves.Break object at 0x0000018112535930>
# <bart_playground.moves.Combine object at 0x000001811262AE00>
# <bart_playground.moves.Combine object at 0x000001811262B9A0>
# <bart_playground.moves.Combine object at 0x000001811269BEE0>
# Running iteration 200
# <bart_playground.moves.Break object at 0x000001811269AF80>
# <bart_playground.moves.Combine object at 0x000001811269BB50>
# <bart_playground.moves.Combine object at 0x0000018112707F70>
# <bart_playground.moves.Combine object at 0x000001811269AF80>
# <bart_playground.moves.Combine object at 0x000001811269AF80>
# <bart_playground.moves.Combine object at 0x0000018112707EE0>
# <bart_playground.moves.Combine object at 0x000001811277B2E0>
# <bart_playground.moves.Break object at 0x000001811277B220>
# <bart_playground.moves.Break object at 0x000001811277B7C0>
# <bart_playground.moves.Combine object at 0x000001811277B610>
# Running iteration 210
# <bart_playground.moves.Break object at 0x00000181127F7190>
# <bart_playground.moves.Combine object at 0x000001811277B610>
# <bart_playground.moves.Break object at 0x00000181127F7520>
# <bart_playground.moves.Combine object at 0x000001811277B610>
# <bart_playground.moves.Break object at 0x00000181127F5E40>
# <bart_playground.moves.Break object at 0x000001811285CCA0>
# <bart_playground.moves.Break object at 0x000001811285F4C0>
# <bart_playground.moves.Break object at 0x00000181138A7730>
# <bart_playground.moves.Combine object at 0x000001811285F4C0>
# <bart_playground.moves.Break object at 0x00000181138A76D0>
# Running iteration 220
# <bart_playground.moves.Combine object at 0x00000181138A6B60>
# <bart_playground.moves.Break object at 0x00000181138A76D0>
# <bart_playground.moves.Combine object at 0x000001811391B760>
# <bart_playground.moves.Break object at 0x0000018113919990>
# <bart_playground.moves.Combine object at 0x000001811391B760>
# <bart_playground.moves.Break object at 0x000001811391B760>
# <bart_playground.moves.Break object at 0x000001811398EA40>
# <bart_playground.moves.Combine object at 0x000001811398ED10>
# <bart_playground.moves.Combine object at 0x000001811398FEB0>
# <bart_playground.moves.Combine object at 0x000001811398FEB0>
# Running iteration 230
# <bart_playground.moves.Break object at 0x00000181139EFD00>
# <bart_playground.moves.Break object at 0x00000181139EEBC0>
# <bart_playground.moves.Break object at 0x00000181139ED720>
# <bart_playground.moves.Combine object at 0x0000018113A6BF40>
# <bart_playground.moves.Combine object at 0x00000181139EFD00>
# <bart_playground.moves.Break object at 0x0000018113A69060>
# <bart_playground.moves.Combine object at 0x0000018113ADB1F0>
# <bart_playground.moves.Combine object at 0x0000018113AD8250>
# <bart_playground.moves.Combine object at 0x0000018113A6B0A0>
# <bart_playground.moves.Break object at 0x0000018113ADAA70>
# Running iteration 240
# <bart_playground.moves.Break object at 0x0000018113ADBE50>
# <bart_playground.moves.Break object at 0x0000018113B530D0>
# <bart_playground.moves.Combine object at 0x0000018113ADB1F0>
# <bart_playground.moves.Combine object at 0x0000018113B51900>
# <bart_playground.moves.Break object at 0x0000018113B53730>
# <bart_playground.moves.Combine object at 0x0000018113BBD6F0>
# <bart_playground.moves.Combine object at 0x0000018113B53730>
# <bart_playground.moves.Break object at 0x0000018113BBF5E0>
# <bart_playground.moves.Combine object at 0x0000018113BBF640>
# <bart_playground.moves.Combine object at 0x0000018113C1FBE0>
# Running iteration 250
# <bart_playground.moves.Combine object at 0x0000018113C1D450>
# <bart_playground.moves.Combine object at 0x0000018113C1F2E0>
# <bart_playground.moves.Break object at 0x0000018113C1D450>
# <bart_playground.moves.Break object at 0x0000018113C9F3A0>
# <bart_playground.moves.Combine object at 0x0000018113C1F2E0>
# <bart_playground.moves.Combine object at 0x0000018113C9F790>
# <bart_playground.moves.Combine object at 0x0000018113C9F790>
# <bart_playground.moves.Break object at 0x0000018113D0FB20>
# <bart_playground.moves.Combine object at 0x0000018113C9F790>
# <bart_playground.moves.Break object at 0x0000018113D0ED70>
# Running iteration 260
# <bart_playground.moves.Combine object at 0x0000018113D0ED70>
# <bart_playground.moves.Combine object at 0x0000018114D4FE80>
# <bart_playground.moves.Combine object at 0x0000018114D4FF40>
# <bart_playground.moves.Combine object at 0x0000018114D4D0C0>
# <bart_playground.moves.Combine object at 0x0000018114D4DB40>
# <bart_playground.moves.Break object at 0x0000018114D4FF40>
# <bart_playground.moves.Combine object at 0x0000018114DAFEB0>
# <bart_playground.moves.Combine object at 0x0000018114DAD780>
# <bart_playground.moves.Combine object at 0x0000018114DADC00>
# <bart_playground.moves.Break object at 0x0000018114DAFEB0>
# Running iteration 270
# <bart_playground.moves.Break object at 0x0000018114E1B370>
# <bart_playground.moves.Break object at 0x0000018114DAFEB0>
# <bart_playground.moves.Break object at 0x0000018114E188B0>
# <bart_playground.moves.Combine object at 0x0000018114E1AC80>
# <bart_playground.moves.Combine object at 0x0000018114E8AEF0>
# <bart_playground.moves.Break object at 0x0000018114E8BA00>
# <bart_playground.moves.Combine object at 0x0000018114E8AA40>
# <bart_playground.moves.Break object at 0x0000018114E8BA00>
# <bart_playground.moves.Combine object at 0x0000018114E8AA40>
# <bart_playground.moves.Combine object at 0x0000018114EF9CC0>
# Running iteration 280
# <bart_playground.moves.Combine object at 0x0000018114EFAA70>
# <bart_playground.moves.Break object at 0x0000018114EFB2B0>
# <bart_playground.moves.Combine object at 0x0000018114EFB6A0>
# <bart_playground.moves.Break object at 0x00000181168FF5B0>
# <bart_playground.moves.Break object at 0x00000181168FE050>
# <bart_playground.moves.Break object at 0x00000181168FFA60>
# <bart_playground.moves.Break object at 0x00000181168FFA60>
# <bart_playground.moves.Combine object at 0x00000181168FFA60>
# <bart_playground.moves.Combine object at 0x000001811696F0D0>
# <bart_playground.moves.Combine object at 0x00000181168FFA60>
# Running iteration 290
# <bart_playground.moves.Combine object at 0x000001811696E950>
# <bart_playground.moves.Combine object at 0x000001811696E950>
# <bart_playground.moves.Break object at 0x00000181169CF730>
# <bart_playground.moves.Combine object at 0x00000181169CE2F0>
# <bart_playground.moves.Break object at 0x00000181169CFAF0>
# <bart_playground.moves.Break object at 0x00000181169CE2F0>
# <bart_playground.moves.Combine object at 0x0000018116A3B4C0>
# <bart_playground.moves.Combine object at 0x00000181169CE2F0>
# <bart_playground.moves.Break object at 0x0000018116A3B2B0>
# <bart_playground.moves.Break object at 0x0000018116A3AE60>
# Running iteration 300
# <bart_playground.moves.Combine object at 0x0000018116A3BE20>
# <bart_playground.moves.Break object at 0x0000018116AA78B0>
# <bart_playground.moves.Break object at 0x0000018116A3B4C0>
# <bart_playground.moves.Combine object at 0x0000018116AA6A40>
# <bart_playground.moves.Break object at 0x0000018116AA6A40>
# <bart_playground.moves.Combine object at 0x0000018117ADF220>
# <bart_playground.moves.Combine object at 0x0000018117ADDD80>
# <bart_playground.moves.Combine object at 0x0000018117ADE560>
# <bart_playground.moves.Combine object at 0x0000018117ADF580>
# <bart_playground.moves.Break object at 0x0000018117ADDD80>
# Running iteration 310
# <bart_playground.moves.Break object at 0x0000018117B56800>
# <bart_playground.moves.Break object at 0x0000018117ADDD80>
# <bart_playground.moves.Break object at 0x0000018117B540A0>
# <bart_playground.moves.Combine object at 0x0000018117B56BF0>
# <bart_playground.moves.Break object at 0x0000018117B540A0>
# <bart_playground.moves.Combine object at 0x0000018117BDB1C0>
# <bart_playground.moves.Break object at 0x0000018117B540A0>
# <bart_playground.moves.Combine object at 0x0000018117BDB3D0>
# <bart_playground.moves.Combine object at 0x0000018117C47E50>
# <bart_playground.moves.Combine object at 0x0000018117BDB3D0>
# Running iteration 320
# <bart_playground.moves.Combine object at 0x0000018117C46AD0>
# <bart_playground.moves.Combine object at 0x0000018117C47580>
# <bart_playground.moves.Combine object at 0x0000018117C46AD0>
# <bart_playground.moves.Break object at 0x0000018117CC73A0>
# <bart_playground.moves.Break object at 0x0000018117C47580>
# <bart_playground.moves.Break object at 0x0000018117CC6A70>
# <bart_playground.moves.Combine object at 0x0000018117CC79D0>
# <bart_playground.moves.Combine object at 0x0000018117CC79D0>
# <bart_playground.moves.Break object at 0x0000018117CC5810>
# <bart_playground.moves.Combine object at 0x0000018117D3A6E0>
# Running iteration 330
# <bart_playground.moves.Break object at 0x0000018117CC5810>
# <bart_playground.moves.Break object at 0x0000018117D3AA40>
# <bart_playground.moves.Break object at 0x0000018117CC5810>
# <bart_playground.moves.Break object at 0x0000018117D3BD30>
# <bart_playground.moves.Break object at 0x0000018117D3A6E0>
# <bart_playground.moves.Break object at 0x0000018117DB3730>
# <bart_playground.moves.Break object at 0x0000018117D3A6E0>
# <bart_playground.moves.Combine object at 0x0000018117DB3730>
# <bart_playground.moves.Combine object at 0x0000018117E27F40>
# <bart_playground.moves.Break object at 0x0000018117E270A0>
# Running iteration 340
# <bart_playground.moves.Break object at 0x0000018117E27400>
# <bart_playground.moves.Break object at 0x0000018117E26140>
# <bart_playground.moves.Break object at 0x0000018118E7F6A0>
# <bart_playground.moves.Break object at 0x0000018117E26140>
# <bart_playground.moves.Break object at 0x0000018118E7F460>
# <bart_playground.moves.Break object at 0x0000018117E26140>
# <bart_playground.moves.Break object at 0x0000018118E7F460>
# <bart_playground.moves.Combine object at 0x0000018118EFF220>
# <bart_playground.moves.Combine object at 0x0000018118E7FAC0>
# <bart_playground.moves.Combine object at 0x000001810A5D8670>
# Running iteration 350
# <bart_playground.moves.Break object at 0x000001810D9828F0>
# <bart_playground.moves.Combine object at 0x000001810A5D8670>
# <bart_playground.moves.Break object at 0x000001810A5D8670>
# <bart_playground.moves.Break object at 0x0000018118F83D60>
# <bart_playground.moves.Break object at 0x000001810A5D8670>
# <bart_playground.moves.Break object at 0x0000018118F83D60>
# <bart_playground.moves.Break object at 0x0000018118FF7850>
# <bart_playground.moves.Break object at 0x000001810A5D8670>
# <bart_playground.moves.Break object at 0x0000018118F83D60>
# <bart_playground.moves.Break object at 0x0000018118FF5F90>
# Running iteration 360
# <bart_playground.moves.Combine object at 0x0000018119089C90>
# <bart_playground.moves.Break object at 0x000001811908BD90>
# <bart_playground.moves.Break object at 0x000001811908BDF0>
# <bart_playground.moves.Combine object at 0x000001811910F1C0>
# <bart_playground.moves.Combine object at 0x000001811910F280>
# <bart_playground.moves.Break object at 0x000001811910D900>
# <bart_playground.moves.Break object at 0x000001811910E650>
# <bart_playground.moves.Break object at 0x00000181199C30A0>
# <bart_playground.moves.Break object at 0x00000181199C31C0>
# <bart_playground.moves.Break object at 0x00000181199C29B0>
# Running iteration 370
# <bart_playground.moves.Break object at 0x00000181199C3490>
# <bart_playground.moves.Combine object at 0x0000018119A3B370>
# <bart_playground.moves.Combine object at 0x0000018119A3AB60>
# <bart_playground.moves.Break object at 0x0000018119A3AEC0>
# <bart_playground.moves.Combine object at 0x0000018119A3B580>
# <bart_playground.moves.Combine object at 0x000001811AAA2D70>
# <bart_playground.moves.Break object at 0x000001811AAA0FA0>
# <bart_playground.moves.Combine object at 0x000001811AAA3280>
# <bart_playground.moves.Combine object at 0x000001811AAA2D70>
# <bart_playground.moves.Combine object at 0x000001811AAA3280>
# Running iteration 380
# <bart_playground.moves.Combine object at 0x000001811AB19570>
# <bart_playground.moves.Combine object at 0x000001811AB1A710>
# <bart_playground.moves.Combine object at 0x000001811AB19570>
# <bart_playground.moves.Break object at 0x000001811ABA7550>
# <bart_playground.moves.Break object at 0x000001811AB19570>
# <bart_playground.moves.Combine object at 0x000001811ABA5CC0>
# <bart_playground.moves.Combine object at 0x000001811ABA78E0>
# <bart_playground.moves.Combine object at 0x000001811AC47310>
# <bart_playground.moves.Break object at 0x000001811ABA5CC0>
# <bart_playground.moves.Break object at 0x000001811AC45B10>
# Running iteration 390
# <bart_playground.moves.Combine object at 0x000001811ACC30D0>
# <bart_playground.moves.Break object at 0x000001811AC45B10>
# <bart_playground.moves.Combine object at 0x000001811ACC3940>
# <bart_playground.moves.Break object at 0x000001811ACC0C70>
# <bart_playground.moves.Combine object at 0x000001811ACC3B80>
# <bart_playground.moves.Combine object at 0x000001811ACC3C70>
# <bart_playground.moves.Break object at 0x000001811AD4AFB0>
# <bart_playground.moves.Break object at 0x000001811ACC0C70>
# <bart_playground.moves.Break object at 0x000001811AD49E70>
# <bart_playground.moves.Combine object at 0x000001811AD49D50>

# %%
profiler = Profiler()
profiler.start()
bart = ChangeNumTreeBART(ndpost=300, nskip=100, n_trees=100, proposal_probs=proposal_probs)
bart.fit(X_train, y_train)
profiler.stop()
profiler.print()
# Out:
# Running iteration 0
# <bart_playground.moves.Break object at 0x0000018105AFB070>
# <bart_playground.moves.Combine object at 0x0000018105F070A0>
# <bart_playground.moves.Combine object at 0x0000018105F070A0>
# <bart_playground.moves.Combine object at 0x000001810DA8DCF0>
# <bart_playground.moves.Combine object at 0x000001810A5D9720>
# <bart_playground.moves.Break object at 0x000001810DA8DCF0>
# <bart_playground.moves.Break object at 0x000001810A5D9720>
# <bart_playground.moves.Break object at 0x0000018118F82530>
# <bart_playground.moves.Break object at 0x000001810DA8DCF0>
# <bart_playground.moves.Break object at 0x000001810DA8DCF0>
# Running iteration 10
# <bart_playground.moves.Break object at 0x0000018118FF7730>
# <bart_playground.moves.Combine object at 0x000001810DA8DCF0>
# <bart_playground.moves.Break object at 0x000001810DA8DCF0>
# <bart_playground.moves.Combine object at 0x00000181199C3A30>
# <bart_playground.moves.Combine object at 0x00000181199C2DD0>
# <bart_playground.moves.Combine object at 0x00000181199C35B0>
# <bart_playground.moves.Break object at 0x000001811AB1A740>
# <bart_playground.moves.Combine object at 0x000001811AB1AAD0>
# <bart_playground.moves.Combine object at 0x000001811AB1B760>
# <bart_playground.moves.Combine object at 0x000001811AB1BE80>
# Running iteration 20
# <bart_playground.moves.Combine object at 0x000001811AD48670>
# <bart_playground.moves.Break object at 0x000001810DA36980>
# <bart_playground.moves.Combine object at 0x000001811AD497B0>
# <bart_playground.moves.Break object at 0x000001811AD497B0>
# <bart_playground.moves.Combine object at 0x000001811ADC2800>
# <bart_playground.moves.Combine object at 0x000001811ADC32E0>
# <bart_playground.moves.Break object at 0x000001811ADC3A00>
# <bart_playground.moves.Combine object at 0x000001811AE43EB0>
# <bart_playground.moves.Break object at 0x000001811AE42F20>
# <bart_playground.moves.Combine object at 0x000001811AE43130>
# Running iteration 30
# <bart_playground.moves.Break object at 0x000001811AE43130>
# <bart_playground.moves.Break object at 0x0000018116A93550>
# <bart_playground.moves.Break object at 0x0000018116A90B50>
# <bart_playground.moves.Combine object at 0x0000018116A92110>
# <bart_playground.moves.Combine object at 0x0000018117C72BF0>
# <bart_playground.moves.Combine object at 0x0000018116A92B00>
# <bart_playground.moves.Combine object at 0x0000018117C72230>
# <bart_playground.moves.Break object at 0x0000018117C72BF0>
# <bart_playground.moves.Break object at 0x0000018117C72230>
# <bart_playground.moves.Break object at 0x0000018119077580>
# Running iteration 40
# <bart_playground.moves.Combine object at 0x0000018119077790>
# <bart_playground.moves.Break object at 0x000001811101A050>
# <bart_playground.moves.Break object at 0x0000018119077790>
# <bart_playground.moves.Break object at 0x0000018119077790>
# <bart_playground.moves.Combine object at 0x0000018119077790>
# <bart_playground.moves.Break object at 0x00000181127DFD30>
# <bart_playground.moves.Combine object at 0x00000181127DF700>
# <bart_playground.moves.Break object at 0x00000181127DFD60>
# <bart_playground.moves.Combine object at 0x000001811124F400>
# <bart_playground.moves.Break object at 0x000001811124E4D0>
# Running iteration 50
# <bart_playground.moves.Combine object at 0x000001811124FB20>
# <bart_playground.moves.Combine object at 0x000001811124FB20>
# <bart_playground.moves.Combine object at 0x000001810E043F70>
# <bart_playground.moves.Combine object at 0x000001811124FB20>
# <bart_playground.moves.Combine object at 0x000001810E040D30>
# <bart_playground.moves.Combine object at 0x0000018114E0F340>
# <bart_playground.moves.Combine object at 0x0000018114E0E710>
# <bart_playground.moves.Break object at 0x0000018114E0DC30>
# <bart_playground.moves.Break object at 0x0000018114E0DC30>
# <bart_playground.moves.Break object at 0x000001810F55B760>
# Running iteration 60
# <bart_playground.moves.Break object at 0x000001810F55AB90>
# <bart_playground.moves.Break object at 0x000001810F55ACB0>
# <bart_playground.moves.Break object at 0x000001810F8A0460>
# <bart_playground.moves.Break object at 0x000001810F8A2110>
# <bart_playground.moves.Combine object at 0x000001810F8A3BB0>
# <bart_playground.moves.Combine object at 0x000001810F8A3BB0>
# <bart_playground.moves.Combine object at 0x00000181123E7940>
# <bart_playground.moves.Break object at 0x00000181123E6080>
# <bart_playground.moves.Combine object at 0x00000181123E7DF0>
# <bart_playground.moves.Combine object at 0x0000018113D0FF40>
# Running iteration 70
# <bart_playground.moves.Break object at 0x0000018113D0ED10>
# <bart_playground.moves.Combine object at 0x0000018113D0ED10>
# <bart_playground.moves.Break object at 0x0000018113D0ED10>
# <bart_playground.moves.Combine object at 0x0000018117D63580>
# <bart_playground.moves.Combine object at 0x0000018117D61C90>
# <bart_playground.moves.Combine object at 0x0000018117D639A0>
# <bart_playground.moves.Break object at 0x0000018117D639A0>
# <bart_playground.moves.Combine object at 0x0000018117ADB8E0>
# <bart_playground.moves.Combine object at 0x0000018117ADB280>
# <bart_playground.moves.Combine object at 0x0000018117ADB850>
# Running iteration 80
# <bart_playground.moves.Combine object at 0x0000018117ADB730>
# <bart_playground.moves.Combine object at 0x000001811698FC10>
# <bart_playground.moves.Combine object at 0x000001811698FB50>
# <bart_playground.moves.Break object at 0x000001811698F040>
# <bart_playground.moves.Combine object at 0x000001811698FC10>
# <bart_playground.moves.Break object at 0x0000018113927A00>
# <bart_playground.moves.Break object at 0x0000018113925ED0>
# <bart_playground.moves.Combine object at 0x0000018113925ED0>
# <bart_playground.moves.Combine object at 0x0000018113925ED0>
# <bart_playground.moves.Combine object at 0x000001810E3BF940>
# Running iteration 90
# <bart_playground.moves.Break object at 0x000001810E3BFD90>
# <bart_playground.moves.Break object at 0x000001810E3BFBE0>
# <bart_playground.moves.Combine object at 0x000001810E3BFBE0>
# <bart_playground.moves.Break object at 0x000001810F5DBAF0>
# <bart_playground.moves.Combine object at 0x000001810E3BFBE0>
# <bart_playground.moves.Break object at 0x000001810E3BFBE0>
# <bart_playground.moves.Break object at 0x000001810E3BFBE0>
# <bart_playground.moves.Break object at 0x0000018110AE7D90>
# <bart_playground.moves.Combine object at 0x000001810E3BFBE0>
# <bart_playground.moves.Combine object at 0x000001810E3BFBE0>
# Running iteration 100
# <bart_playground.moves.Combine object at 0x000001810E3BFBE0>
# <bart_playground.moves.Break object at 0x00000181111BFE50>
# <bart_playground.moves.Combine object at 0x00000181111BE2C0>
# <bart_playground.moves.Combine object at 0x00000181111BE2C0>
# <bart_playground.moves.Break object at 0x00000181111BE2C0>
# <bart_playground.moves.Break object at 0x000001810F68F7C0>
# <bart_playground.moves.Break object at 0x000001810F68F070>
# <bart_playground.moves.Combine object at 0x000001810F68F7C0>
# <bart_playground.moves.Break object at 0x000001810F68F7C0>
# <bart_playground.moves.Break object at 0x0000018113BB7B20>
# Running iteration 110
# <bart_playground.moves.Break object at 0x000001810F68F7C0>
# <bart_playground.moves.Combine object at 0x0000018113BB7430>
# <bart_playground.moves.Combine object at 0x000001810F68F7C0>
# <bart_playground.moves.Break object at 0x0000018113BB7430>
# <bart_playground.moves.Combine object at 0x000001810E235E40>
# <bart_playground.moves.Combine object at 0x000001810E237D90>
# <bart_playground.moves.Combine object at 0x000001810E237D90>
# <bart_playground.moves.Break object at 0x0000018110A2FBE0>
# <bart_playground.moves.Break object at 0x0000018110A2E050>
# <bart_playground.moves.Break object at 0x0000018110A2FBE0>
# Running iteration 120
# <bart_playground.moves.Break object at 0x0000018110A2FBE0>
# <bart_playground.moves.Break object at 0x00000181126C1E10>
# <bart_playground.moves.Combine object at 0x00000181126C2FB0>
# <bart_playground.moves.Break object at 0x00000181126C1E10>
# <bart_playground.moves.Break object at 0x00000181126C1E10>
# <bart_playground.moves.Combine object at 0x0000018114E9ADD0>
# <bart_playground.moves.Break object at 0x00000181126C1E10>
# <bart_playground.moves.Break object at 0x0000018114E9B0A0>
# <bart_playground.moves.Combine object at 0x0000018113A03AF0>
# <bart_playground.moves.Break object at 0x0000018114E9B0A0>
# Running iteration 130
# <bart_playground.moves.Combine object at 0x0000018113A01270>
# <bart_playground.moves.Combine object at 0x000001811BE532E0>
# <bart_playground.moves.Combine object at 0x0000018113A01270>
# <bart_playground.moves.Combine object at 0x000001811BE53340>
# <bart_playground.moves.Break object at 0x000001811BE52800>
# <bart_playground.moves.Break object at 0x000001811BE536A0>
# <bart_playground.moves.Break object at 0x000001811BF4AE90>
# <bart_playground.moves.Break object at 0x000001811BF4A380>
# <bart_playground.moves.Break object at 0x000001811BF4BD00>
# <bart_playground.moves.Break object at 0x000001811BF4BD00>
# Running iteration 140
# <bart_playground.moves.Combine object at 0x000001811C097250>
# <bart_playground.moves.Break object at 0x000001811BF4BD00>
# <bart_playground.moves.Break object at 0x000001811BF4BD00>
# <bart_playground.moves.Combine object at 0x000001811BF4BD00>
# <bart_playground.moves.Break object at 0x000001811C1BBAF0>
# <bart_playground.moves.Combine object at 0x000001811BF4BD00>
# <bart_playground.moves.Break object at 0x000001811BF4BD00>
# <bart_playground.moves.Combine object at 0x000001811C31ECB0>
# <bart_playground.moves.Break object at 0x000001811C31D360>
# <bart_playground.moves.Break object at 0x000001811C31DF90>
# Running iteration 150
# <bart_playground.moves.Combine object at 0x000001811C493400>
# <bart_playground.moves.Combine object at 0x000001811C491C00>
# <bart_playground.moves.Break object at 0x000001811C493AF0>
# <bart_playground.moves.Break object at 0x000001811C493EE0>
# <bart_playground.moves.Combine object at 0x000001811C493F40>
# <bart_playground.moves.Combine object at 0x000001811C61FBE0>
# <bart_playground.moves.Break object at 0x000001811C61E1A0>
# <bart_playground.moves.Combine object at 0x000001811C61EC50>
# <bart_playground.moves.Break object at 0x000001811C78FFA0>
# <bart_playground.moves.Break object at 0x000001811C61FE20>
# Running iteration 160
# <bart_playground.moves.Break object at 0x000001811C78F490>
# <bart_playground.moves.Combine object at 0x000001811C78F490>
# <bart_playground.moves.Break object at 0x000001811C933280>
# <bart_playground.moves.Combine object at 0x000001811C932110>
# <bart_playground.moves.Combine object at 0x000001811C9332B0>
# <bart_playground.moves.Combine object at 0x000001811C932110>
# <bart_playground.moves.Break object at 0x000001811CAA6290>
# <bart_playground.moves.Break object at 0x000001811CAA78B0>
# <bart_playground.moves.Combine object at 0x000001811CBF33D0>
# <bart_playground.moves.Combine object at 0x000001811CBF2170>
# Running iteration 170
# <bart_playground.moves.Combine object at 0x000001811CBF1AB0>
# <bart_playground.moves.Break object at 0x000001811CBF36A0>
# <bart_playground.moves.Break object at 0x000001811CBF36A0>
# <bart_playground.moves.Break object at 0x000001811CBF36A0>
# <bart_playground.moves.Break object at 0x000001811CD8E290>
# <bart_playground.moves.Break object at 0x000001811CD8EFE0>
# <bart_playground.moves.Combine object at 0x000001811CD8EFE0>
# <bart_playground.moves.Break object at 0x000001811CF0A9E0>
# <bart_playground.moves.Break object at 0x000001811CF096C0>
# <bart_playground.moves.Break object at 0x000001811CF096C0>
# Running iteration 180
# <bart_playground.moves.Break object at 0x000001811D0A7130>
# <bart_playground.moves.Combine object at 0x000001811D0A62F0>
# <bart_playground.moves.Combine object at 0x000001811D0A5B10>
# <bart_playground.moves.Combine object at 0x000001811D217E80>
# <bart_playground.moves.Break object at 0x000001811D0A5B10>
# <bart_playground.moves.Combine object at 0x000001811D214FD0>
# <bart_playground.moves.Combine object at 0x000001811D214FD0>
# <bart_playground.moves.Combine object at 0x000001811D214FD0>
# <bart_playground.moves.Break object at 0x000001811D36E6E0>
# <bart_playground.moves.Combine object at 0x000001811D36D6C0>
# Running iteration 190
# <bart_playground.moves.Combine object at 0x000001811D36E6E0>
# <bart_playground.moves.Combine object at 0x000001811D36D6C0>
# <bart_playground.moves.Combine object at 0x000001811D5126B0>
# <bart_playground.moves.Combine object at 0x000001811D513520>
# <bart_playground.moves.Break object at 0x000001811D513820>
# <bart_playground.moves.Combine object at 0x000001811D6ABE80>
# <bart_playground.moves.Break object at 0x000001811D513820>
# <bart_playground.moves.Combine object at 0x000001811D6AB070>
# <bart_playground.moves.Combine object at 0x000001811D6AB070>
# <bart_playground.moves.Combine object at 0x000001811D8F36A0>
# Running iteration 200
# <bart_playground.moves.Break object at 0x000001811D8F34F0>
# <bart_playground.moves.Combine object at 0x000001811D8F3E80>
# <bart_playground.moves.Combine object at 0x000001811D8F3E80>
# <bart_playground.moves.Combine object at 0x000001811DAADA20>
# <bart_playground.moves.Combine object at 0x000001811DAAF7C0>
# <bart_playground.moves.Combine object at 0x000001811DAAF7C0>
# <bart_playground.moves.Combine object at 0x000001811DC6F850>
# <bart_playground.moves.Break object at 0x000001811DAAF7C0>
# <bart_playground.moves.Break object at 0x000001811DC6F670>
# <bart_playground.moves.Combine object at 0x000001811DAAF7C0>
# Running iteration 210
# <bart_playground.moves.Break object at 0x000001811DE63700>
# <bart_playground.moves.Combine object at 0x000001811DC6D3F0>
# <bart_playground.moves.Break object at 0x000001811DE63A90>
# <bart_playground.moves.Combine object at 0x000001811DE623B0>
# <bart_playground.moves.Break object at 0x000001810D982B60>
# <bart_playground.moves.Break object at 0x000001811DE63A90>
# <bart_playground.moves.Break object at 0x000001811E016CB0>
# <bart_playground.moves.Break object at 0x000001811DE63A90>
# <bart_playground.moves.Combine object at 0x000001811E1B3910>
# <bart_playground.moves.Break object at 0x000001811E1B2410>
# Running iteration 220
# <bart_playground.moves.Combine object at 0x000001811E1B32E0>
# <bart_playground.moves.Break object at 0x000001811E1B2410>
# <bart_playground.moves.Combine object at 0x000001811E323D60>
# <bart_playground.moves.Break object at 0x000001811E322410>
# <bart_playground.moves.Combine object at 0x000001811E322410>
# <bart_playground.moves.Break object at 0x000001811E475F60>
# <bart_playground.moves.Break object at 0x000001811E322410>
# <bart_playground.moves.Combine object at 0x000001811E477190>
# <bart_playground.moves.Combine object at 0x000001811E477190>
# <bart_playground.moves.Combine object at 0x000001811E5D3820>
# Running iteration 230
# <bart_playground.moves.Break object at 0x000001811E477190>
# <bart_playground.moves.Break object at 0x000001811E5D3850>
# <bart_playground.moves.Break object at 0x000001811E5D0F70>
# <bart_playground.moves.Combine object at 0x000001811E75B010>
# <bart_playground.moves.Combine object at 0x000001811E5D3850>
# <bart_playground.moves.Break object at 0x000001811E75A650>
# <bart_playground.moves.Combine object at 0x000001811E75B910>
# <bart_playground.moves.Combine object at 0x000001811E8E35E0>
# <bart_playground.moves.Combine object at 0x000001811E8E0EB0>
# <bart_playground.moves.Break object at 0x000001811E8E3280>
# Running iteration 240
# <bart_playground.moves.Break object at 0x000001811E8E0EB0>
# <bart_playground.moves.Break object at 0x000001811EA5F790>
# <bart_playground.moves.Combine object at 0x000001811EA5D720>
# <bart_playground.moves.Combine object at 0x000001811EA5EE00>
# <bart_playground.moves.Break object at 0x000001811EA5FDF0>
# <bart_playground.moves.Combine object at 0x000001811EBE1D80>
# <bart_playground.moves.Combine object at 0x000001811EBE35B0>
# <bart_playground.moves.Break object at 0x000001811EBE3DC0>
# <bart_playground.moves.Combine object at 0x000001811ED8BD00>
# <bart_playground.moves.Combine object at 0x000001811EBE39A0>
# Running iteration 250
# <bart_playground.moves.Combine object at 0x000001811ED8A1A0>
# <bart_playground.moves.Combine object at 0x000001811ED8BDC0>
# <bart_playground.moves.Break object at 0x000001811ED8A1A0>
# <bart_playground.moves.Break object at 0x000001811ED8BDC0>
# <bart_playground.moves.Combine object at 0x000001811EF10610>
# <bart_playground.moves.Combine object at 0x000001811ED8BDC0>
# <bart_playground.moves.Combine object at 0x000001811ED8BDC0>
# <bart_playground.moves.Break object at 0x000001811F0AE800>
# <bart_playground.moves.Combine object at 0x000001811F0ADD80>
# <bart_playground.moves.Break object at 0x000001811F0AF370>
# Running iteration 260
# <bart_playground.moves.Combine object at 0x000001811F0AF370>
# <bart_playground.moves.Combine object at 0x000001811F20F580>
# <bart_playground.moves.Combine object at 0x000001811F20C850>
# <bart_playground.moves.Combine object at 0x000001811F20DCF0>
# <bart_playground.moves.Combine object at 0x000001811F20E680>
# <bart_playground.moves.Break object at 0x000001811F3A7430>
# <bart_playground.moves.Combine object at 0x000001811F3A7970>
# <bart_playground.moves.Combine object at 0x000001811F3A6D10>
# <bart_playground.moves.Combine object at 0x000001811F3A7040>
# <bart_playground.moves.Break object at 0x000001811F3A7970>
# Running iteration 270
# <bart_playground.moves.Break object at 0x000001811F537E50>
# <bart_playground.moves.Break object at 0x000001811F3A6D10>
# <bart_playground.moves.Break object at 0x000001811F3A6D10>
# <bart_playground.moves.Combine object at 0x000001811F536AD0>
# <bart_playground.moves.Combine object at 0x000001811F6E77F0>
# <bart_playground.moves.Break object at 0x000001811F6E6E60>
# <bart_playground.moves.Combine object at 0x000001811F6E6F80>
# <bart_playground.moves.Break object at 0x000001811F8434C0>
# <bart_playground.moves.Combine object at 0x000001811F6E79A0>
# <bart_playground.moves.Combine object at 0x000001811F8433D0>
# Running iteration 280
# <bart_playground.moves.Combine object at 0x000001811F842C80>
# <bart_playground.moves.Break object at 0x000001811F843700>
# <bart_playground.moves.Combine object at 0x000001811F843CA0>
# <bart_playground.moves.Break object at 0x000001811F9DBC70>
# <bart_playground.moves.Break object at 0x000001811F843700>
# <bart_playground.moves.Break object at 0x000001811F9DBC70>
# <bart_playground.moves.Break object at 0x000001811FB97850>
# <bart_playground.moves.Combine object at 0x000001811F9DBF70>
# <bart_playground.moves.Combine object at 0x000001811FB96800>
# <bart_playground.moves.Combine object at 0x000001811FB954B0>
# Running iteration 290
# <bart_playground.moves.Combine object at 0x000001811FB97100>
# <bart_playground.moves.Combine object at 0x000001811FB97100>
# <bart_playground.moves.Break object at 0x000001811FD27C40>
# <bart_playground.moves.Combine object at 0x000001811FD26800>
# <bart_playground.moves.Break object at 0x000001811FD27FD0>
# <bart_playground.moves.Break object at 0x000001811FEDF9D0>
# <bart_playground.moves.Combine object at 0x000001811FD26800>
# <bart_playground.moves.Combine object at 0x000001811FEDF7C0>
# <bart_playground.moves.Break object at 0x000001811FD26800>
# <bart_playground.moves.Break object at 0x000001811FEDF2B0>
# Running iteration 300
# <bart_playground.moves.Combine object at 0x000001811FEDF7C0>
# <bart_playground.moves.Break object at 0x0000018120092F20>
# <bart_playground.moves.Break object at 0x000001811FEDF2B0>
# <bart_playground.moves.Combine object at 0x0000018120092F20>
# <bart_playground.moves.Break object at 0x0000018120092F20>
# <bart_playground.moves.Combine object at 0x000001812020F7C0>
# <bart_playground.moves.Combine object at 0x000001811FD26800>
# <bart_playground.moves.Combine object at 0x000001812020E650>
# <bart_playground.moves.Combine object at 0x000001811FD26800>
# <bart_playground.moves.Break object at 0x000001812020E650>
# Running iteration 310
# <bart_playground.moves.Break object at 0x000001812020E650>
# <bart_playground.moves.Break object at 0x00000181203929E0>
# <bart_playground.moves.Break object at 0x000001812020E650>
# <bart_playground.moves.Combine object at 0x0000018120392CE0>
# <bart_playground.moves.Break object at 0x000001812020E650>
# <bart_playground.moves.Combine object at 0x00000181205433D0>
# <bart_playground.moves.Break object at 0x0000018120542D10>
# <bart_playground.moves.Combine object at 0x00000181205433D0>
# <bart_playground.moves.Combine object at 0x00000181206CAFE0>
# <bart_playground.moves.Combine object at 0x00000181205433D0>
# Running iteration 320
# <bart_playground.moves.Combine object at 0x00000181206C9A20>
# <bart_playground.moves.Combine object at 0x00000181206C8640>
# <bart_playground.moves.Combine object at 0x00000181206C9A20>
# <bart_playground.moves.Break object at 0x00000181208678B0>
# <bart_playground.moves.Break object at 0x00000181206CA680>
# <bart_playground.moves.Break object at 0x00000181208663B0>
# <bart_playground.moves.Combine object at 0x00000181206CA680>
# <bart_playground.moves.Combine object at 0x00000181206CA680>
# <bart_playground.moves.Break object at 0x00000181209FFDF0>
# <bart_playground.moves.Combine object at 0x00000181209FD480>
# Running iteration 330
# <bart_playground.moves.Break object at 0x00000181209FD840>
# <bart_playground.moves.Break object at 0x00000181209FFDF0>
# <bart_playground.moves.Break object at 0x00000181209FD480>
# <bart_playground.moves.Break object at 0x0000018120B57CD0>
# <bart_playground.moves.Break object at 0x00000181209FFDF0>
# <bart_playground.moves.Break object at 0x0000018120B56EC0>
# <bart_playground.moves.Break object at 0x0000018120B57310>
# <bart_playground.moves.Combine object at 0x0000018120B57310>
# <bart_playground.moves.Combine object at 0x0000018120CF75B0>
# <bart_playground.moves.Break object at 0x0000018120CF7D30>
# Running iteration 340
# <bart_playground.moves.Break object at 0x0000018120CF7580>
# <bart_playground.moves.Break object at 0x0000018120CF7580>
# <bart_playground.moves.Break object at 0x0000018120F4FBB0>
# <bart_playground.moves.Break object at 0x0000018120F4EE00>
# <bart_playground.moves.Break object at 0x0000018120F4FD30>
# <bart_playground.moves.Break object at 0x0000018120F4EE00>
# <bart_playground.moves.Break object at 0x0000018120F4FD30>
# <bart_playground.moves.Combine object at 0x00000181210DAE90>
# <bart_playground.moves.Combine object at 0x0000018120F4EE00>
# <bart_playground.moves.Combine object at 0x00000181210DB100>
# Running iteration 350
# <bart_playground.moves.Break object at 0x000001812126BD30>
# <bart_playground.moves.Combine object at 0x000001812126BB50>
# <bart_playground.moves.Break object at 0x000001812126A2F0>
# <bart_playground.moves.Break object at 0x000001812126B550>
# <bart_playground.moves.Break object at 0x000001812126B790>
# <bart_playground.moves.Break object at 0x0000018121447FD0>
# <bart_playground.moves.Break object at 0x000001812126BBE0>
# <bart_playground.moves.Break object at 0x0000018121446C50>
# <bart_playground.moves.Break object at 0x00000181214459F0>
# <bart_playground.moves.Break object at 0x0000018121446C50>
# Running iteration 360
# <bart_playground.moves.Combine object at 0x0000018121613280>
# <bart_playground.moves.Break object at 0x0000018121446C50>
# <bart_playground.moves.Break object at 0x0000018121613280>
# <bart_playground.moves.Combine object at 0x00000181217BB820>
# <bart_playground.moves.Combine object at 0x00000181217BBA90>
# <bart_playground.moves.Break object at 0x00000181217BA680>
# <bart_playground.moves.Break object at 0x00000181217BBB50>
# <bart_playground.moves.Break object at 0x00000181219675E0>
# <bart_playground.moves.Break object at 0x00000181217BA680>
# <bart_playground.moves.Break object at 0x00000181219650F0>
# Running iteration 370
# <bart_playground.moves.Break object at 0x00000181219673A0>
# <bart_playground.moves.Combine object at 0x0000018121B6BBB0>
# <bart_playground.moves.Combine object at 0x00000181219673A0>
# <bart_playground.moves.Break object at 0x0000018121B6AF20>
# <bart_playground.moves.Combine object at 0x00000181219673A0>
# <bart_playground.moves.Combine object at 0x0000018121B6AF20>
# <bart_playground.moves.Break object at 0x0000018121D39BA0>
# <bart_playground.moves.Combine object at 0x00000181219673A0>
# <bart_playground.moves.Combine object at 0x00000181219673A0>
# <bart_playground.moves.Combine object at 0x0000018121F2BCA0>
# Running iteration 380
# <bart_playground.moves.Combine object at 0x00000181219673A0>
# <bart_playground.moves.Combine object at 0x0000018121F2ABC0>
# <bart_playground.moves.Combine object at 0x00000181219673A0>
# <bart_playground.moves.Break object at 0x00000181220FFCD0>
# <bart_playground.moves.Break object at 0x00000181220FE1A0>
# <bart_playground.moves.Combine object at 0x00000181220FF070>
# <bart_playground.moves.Combine object at 0x00000181220FFCD0>
# <bart_playground.moves.Combine object at 0x0000018122307B80>
# <bart_playground.moves.Break object at 0x0000018122307DF0>
# <bart_playground.moves.Break object at 0x00000181220FFCD0>
# Running iteration 390
# <bart_playground.moves.Combine object at 0x00000181223076A0>
# <bart_playground.moves.Break object at 0x00000181220FFCD0>
# <bart_playground.moves.Combine object at 0x000001812251BF70>
# <bart_playground.moves.Break object at 0x00000181223076A0>
# <bart_playground.moves.Combine object at 0x000001812251B130>
# <bart_playground.moves.Combine object at 0x00000181223076A0>
# <bart_playground.moves.Break object at 0x00000181226DF4F0>
# <bart_playground.moves.Break object at 0x00000181226DC5B0>
# <bart_playground.moves.Break object at 0x00000181226DC160>
# <bart_playground.moves.Combine object at 0x00000181228BB490>
#
#   _     ._   __/__   _ _  _  _ _/_   Recorded: 17:21:31  Samples:  19565
#  /_//_/// /_\ / //_// / //_'/ //     Duration: 19.819    CPU time: 4.531
# /   _/                      v5.0.1
#
# Profile at C:\Users\pyk\AppData\Local\Temp\ipykernel_50476\1188248552.py:2
#
# 19.818 <module>  ..\AppData\Local\Temp\ipykernel_50476\1188248552.py:1
# └─ 19.774 ChangeNumTreeBART.fit  bart_playground\bart.py:23
#    └─ 19.773 NtreeSampler.run  bart_playground\samplers.py:60
#       └─ 19.768 NtreeSampler.one_iter  bart_playground\samplers.py:207
#          ├─ 7.266 NTreePrior.trees_log_mh_ratio  bart_playground\priors.py:146
#          │  ├─ 5.572 NTreePrior.trees_log_marginal_lkhd_ratio  bart_playground\priors.py:122
#          │  │  └─ 5.526 NTreePrior.trees_log_marginal_lkhd  bart_playground\priors.py:535
#          │  │     ├─ 1.560 svd  numpy\linalg\linalg.py:1499
#          │  │     ├─ 1.192 [self]  bart_playground\priors.py
#          │  │     ├─ 1.191 Parameters.leaf_basis  bart_playground\params.py:421
#          │  │     │  ├─ 0.798 <listcomp>  bart_playground\params.py:431
#          │  │     │  │  └─ 0.769 Tree.leaf_basis  bart_playground\params.py:306
#          │  │     │  │     ├─ 0.447 Tree.leaves  bart_playground\params.py:285
#          │  │     │  │     │  └─ 0.378 <listcomp>  bart_playground\params.py:287
#          │  │     │  │     └─ 0.322 [self]  bart_playground\params.py
#          │  │     │  └─ 0.270 hstack  numpy\core\shape_base.py:292
#          │  │     ├─ 0.928 Parameters.evaluate  bart_playground\params.py:382
#          │  │     │  └─ 0.659 <listcomp>  bart_playground\params.py:405
#          │  │     └─ 0.622 sum  numpy\core\fromnumeric.py:2177
#          │  │           [2 frames hidden]  numpy, <built-in>
#          │  └─ 1.669 NTreePrior.trees_log_prior_ratio  bart_playground\priors.py:117
#          │     └─ 1.629 NTreePrior.trees_log_prior  bart_playground\priors.py:507
#          │        ├─ 1.294 [self]  bart_playground\priors.py
#          │        └─ 0.219 sum  numpy\core\fromnumeric.py:2177
#          ├─ 6.166 Grow.propose  bart_playground\moves.py:25
#          │  ├─ 3.001 Parameters.copy  bart_playground\params.py:370
#          │  │  ├─ 2.280 Tree.copy  bart_playground\params.py:51
#          │  │  │  └─ 2.247 Tree.__init__  bart_playground\params.py:11
#          │  │  │     └─ 2.138 deepcopy  copy.py:128
#          │  │  │           [4 frames hidden]  copy, <built-in>
#          │  │  └─ 0.551 deepcopy  copy.py:128
#          │  │        [2 frames hidden]  copy
#          │  ├─ 1.653 Grow.try_propose  bart_playground\moves.py:66
#          │  │  ├─ 0.659 Tree.split_leaf  bart_playground\params.py:140
#          │  │  │  ├─ 0.333 [self]  bart_playground\params.py
#          │  │  │  └─ 0.244 sum  numpy\core\fromnumeric.py:2177
#          │  │  ├─ 0.279 prod  numpy\core\fromnumeric.py:2979
#          │  │  │  └─ 0.252 _wrapreduction  numpy\core\fromnumeric.py:71
#          │  │  ├─ 0.235 Generator.choice  <built-in>
#          │  │  └─ 0.201 Tree.leaves  bart_playground\params.py:285
#          │  ├─ 0.546 Prune.try_propose  bart_playground\moves.py:87
#          │  ├─ 0.337 Break.try_propose  bart_playground\moves.py:201
#          │  │  └─ 0.293 Break.set_subtree_zero  bart_playground\moves.py:185
#          │  │     └─ 0.286 Break.set_subtree_zero  bart_playground\moves.py:185
#          │  │        └─ 0.276 Break.set_subtree_zero  bart_playground\moves.py:185
#          │  │           └─ 0.247 Break.set_subtree_zero  bart_playground\moves.py:185
#          │  │              └─ 0.201 Break.set_subtree_zero  bart_playground\moves.py:185
#          │  ├─ 0.302 Combine.try_propose  bart_playground\moves.py:288
#          │  └─ 0.243 Prune.is_feasible  bart_playground\moves.py:83
#          │     └─ 0.223 Tree.terminal_split_nodes  bart_playground\params.py:297
#          ├─ 2.631 NTreePrior.resample_leaf_vals  bart_playground\priors.py:468
#          │  ├─ 1.590 sqrtm  scipy\linalg\_matfuncs_sqrtm.py:117
#          │  │     [4 frames hidden]  scipy
#          │  ├─ 0.323 [self]  bart_playground\priors.py
#          │  └─ 0.237 Parameters.leaf_basis  bart_playground\params.py:421
#          ├─ 1.350 Parameters.copy  bart_playground\params.py:370
#          │  └─ 1.326 Tree.copy  bart_playground\params.py:51
#          │     └─ 1.314 Tree.__init__  bart_playground\params.py:11
#          │        └─ 1.243 deepcopy  copy.py:128
#          │              [2 frames hidden]  copy
#          ├─ 1.006 NtreeSampler.sample_move  bart_playground\samplers.py:86
#          │  ├─ 0.689 Generator.choice  <built-in>
#          │  └─ 0.293 [self]  bart_playground\samplers.py
#          ├─ 0.792 Parameters.update_leaf_vals  bart_playground\params.py:433
#          │  └─ 0.328 Tree.update_outputs  bart_playground\params.py:265
#          └─ 0.247 [self]  bart_playground\samplers.py

# %%
rf = RandomForestRegressor()
lr = LinearRegression()
rf.fit(X_train, y_train)
lr.fit(X_train, y_train)

btz = bartz.BART.gbart(np.transpose(X_train), y_train, ntree=100, ndpost=200, nskip=100)
btpred_all = btz.predict(np.transpose(X_test))
btpred = np.mean(np.array(btpred_all), axis=0)
# Out:
# Iteration 100/300 P_grow=0.55 P_prune=0.45 A_grow=0.36 A_prune=0.36 (burnin)
# Iteration 200/300 P_grow=0.57 P_prune=0.43 A_grow=0.35 A_prune=0.37
# Iteration 300/300 P_grow=0.57 P_prune=0.43 A_grow=0.39 A_prune=0.40

# %%
bart.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 bart.predict(X_test)
#
# File c:\Users\pyk\bart-playground\bart_playground\bart.py:46, in BART.predict(self, X)
#      42 def predict(self, X):
#      43     """
#      44     Predict using the BART model.
#      45     """
# ---> 46     return np.mean(self.posterior_f(X), axis=1)
#
# File c:\Users\pyk\bart-playground\bart_playground\bart.py:39, in BART.posterior_f(self, X)
#      36 preds = np.zeros((X.shape[0], self.ndpost))
#      37 for k in range(self.ndpost):
#      38     preds[:, k] = self.preprocessor.backtransform_y(
# ---> 39         self.sampler.trace[self.nskip + k].evaluate(X))
#      40 return preds
#
# File c:\Users\pyk\bart-playground\bart_playground\params.py:418, in Parameters.evaluate(self, X, tree_ids, all_except)
#     416     # Iterate over all trees
#     417     for i in tree_ids:
# --> 418         total_output += self.trees[i].evaluate(X)  # Add the tree's output to the total
#     419 return total_output
#
# File c:\Users\pyk\bart-playground\bart_playground\params.py:95, in Tree.evaluate(self, X)
#      93     return self.evals
#      94 else:
# ---> 95     leaf_ids = self.traverse_tree(X)  # Find the leaf node for the input
#      96     return self.leaf_vals[leaf_ids]
#
# File c:\Users\pyk\bart-playground\bart_playground\params.py:70, in Tree.traverse_tree(self, X)
#      68 if not self.split_nodes: # Tree has no splits
#      69     return node_ids
# ---> 70 routing = X[:, self.vars[self.split_nodes]] > self.thresholds[self.split_nodes]
#      71 split_node_counter = 0
#      72 for k in range(len(self.vars)):
#
# TypeError: list indices must be integers or slices, not list

# %%
models = {"bart" : bart, 
          "rf" : rf, 
          "lr" : lr,
          "btz" : btz}
results = {}
for model_name, model in models.items():
    if model_name == "btz":
        results[model_name] = mean_squared_error(y_test, btpred)
    else:
        results[model_name] = mean_squared_error(y_test, model.predict(X_test))
results
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 10
#       8         results[model_name] = mean_squared_error(y_test, btpred)
#       9     else:
# ---> 10         results[model_name] = mean_squared_error(y_test, model.predict(X_test))
#      11 results
#
# File c:\Users\pyk\bart-playground\bart_playground\bart.py:46, in BART.predict(self, X)
#      42 def predict(self, X):
#      43     """
#      44     Predict using the BART model.
#      45     """
# ---> 46     return np.mean(self.posterior_f(X), axis=1)
#
# File c:\Users\pyk\bart-playground\bart_playground\bart.py:39, in BART.posterior_f(self, X)
#      36 preds = np.zeros((X.shape[0], self.ndpost))
#      37 for k in range(self.ndpost):
#      38     preds[:, k] = self.preprocessor.backtransform_y(
# ---> 39         self.sampler.trace[self.nskip + k].evaluate(X))
#      40 return preds
#
# File c:\Users\pyk\bart-playground\bart_playground\params.py:418, in Parameters.evaluate(self, X, tree_ids, all_except)
#     416     # Iterate over all trees
#     417     for i in tree_ids:
# --> 418         total_output += self.trees[i].evaluate(X)  # Add the tree's output to the total
#     419 return total_output
#
# File c:\Users\pyk\bart-playground\bart_playground\params.py:95, in Tree.evaluate(self, X)
#      93     return self.evals
#      94 else:
# ---> 95     leaf_ids = self.traverse_tree(X)  # Find the leaf node for the input
#      96     return self.leaf_vals[leaf_ids]
#
# File c:\Users\pyk\bart-playground\bart_playground\params.py:70, in Tree.traverse_tree(self, X)
#      68 if not self.split_nodes: # Tree has no splits
#      69     return node_ids
# ---> 70 routing = X[:, self.vars[self.split_nodes]] > self.thresholds[self.split_nodes]
#      71 split_node_counter = 0
#      72 for k in range(len(self.vars)):
#
# TypeError: list indices must be integers or slices, not list
