# %%
import numpy as np
import sys

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from bart_playground.bcf.bcf import BCF

# %%
def generate_bcf_data(n=1000, p=10, noise_level=0.5, random_state=42):
    rng = np.random.default_rng(random_state)
    
    X = rng.normal(0, 1, (n, p))
    mu = 2 * np.sin(np.pi * X[:,0]) + X[:,1]**2
    tau = 0.5 * X[:,2] + 0.5 * (X[:,3] > 0)
    z = rng.binomial(1, 0.5, n)
    y = mu + z * tau + rng.normal(0, noise_level, n)
    
    return X, y, z, mu, tau

# Generate data
X, y, z, true_mu, true_tau = generate_bcf_data(n=400)
X_train, X_test, y_train, y_test, z_train, z_test, mu_train, mu_test, tau_train, tau_test = \
    train_test_split(X, y, z, true_mu, true_tau, test_size=0.2, random_state=42)

# %%
bcf = BCF(
    n_mu_trees=200,       # Number of prognostic effect trees
    n_tau_trees=50,       # Number of treatment effect trees
    mu_alpha=0.95,        # Tree depth prior for mu
    mu_beta=2.0,          # Tree depth prior for mu
    tau_alpha=0.5,        # Simpler trees for treatment effects
    tau_beta=3.0,         # Penalize complex tau trees
    tau_k=0.5,            # Regularization for treatment effects
    ndpost=100,          # Posterior samples
    nskip=100,            # Burn-in iterations
    random_state=42
)

bcf.fit(X_train, y_train, z_train)
# Out:
# Running iteration 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 14
#       1 bcf = BCF(
#       2     n_mu_trees=200,       # Number of prognostic effect trees
#       3     n_tau_trees=50,       # Number of treatment effect trees
#    (...)
#      11     random_state=42
#      12 )
# ---> 14 bcf.fit(X_train, y_train, z_train)
#
# File c:\users\drizz\documents\github\bart_playground\bart_playground\bcf\bcf.py:47, in BCF.fit(self, X, y, z)
#      45 self.sampler.prior.fit(data)
#      46 self.sampler.add_data(data)
# ---> 47 self.sampler.run(self.ndpost + self.nskip)
#
# File c:\users\drizz\documents\github\bart_playground\bart_playground\samplers.py:82, in Sampler.run(self, n_iter)
#      80     # print(self.temp_schedule)
#      81     temp = self.temp_schedule(iter)
# ---> 82     current = self.one_iter(current, temp, return_trace=False)
#      83     self.trace.append(current)
#      84 return self.trace
#
# File c:\users\drizz\documents\github\bart_playground\bart_playground\bcf\bcf_sampler.py:70, in BCFSampler.one_iter(self, current, temp, return_trace)
#      66 move_class = self.sample_move("mu")
#      67 move = move_class(
#      68     current=iter_current.mu_view, trees_changed=[k], tol=self.tol
#      69 )
# ---> 70 if move.propose(self.generator): # Check if a valid move was proposed
#      71     # Metropolis–Hastings
#      72     Z = self.generator.uniform(0,1)
#      73     if Z < np.exp(temp * self.prior.trees_log_mh_ratio(move, 'mu')):
#
# File c:\users\drizz\documents\github\bart_playground\bart_playground\moves.py:32, in Move.propose(self, generator)
#      30 for _ in range(self.tol):
#      31     proposed = self.current.copy(self.trees_changed)
# ---> 32     success = self.try_propose(proposed, generator)
#      33     if success:
#      34         self.proposed = proposed
#
# File c:\users\drizz\documents\github\bart_playground\bart_playground\moves.py:69, in Grow.try_propose(self, proposed, generator)
#      67 tree = proposed.trees[self.trees_changed[0]]
#      68 node_id = generator.choice(tree.leaves)
# ---> 69 var = generator.integers(tree.data.p)
#      70 threshold = generator.choice(tree.data.thresholds[var])
#      71 success = tree.split_leaf(node_id, var, threshold)
#
# AttributeError: 'Tree' object has no attribute 'data'

# %%
bcf_result = bcf.predict_components(X_test, z_test)

# %%
print(true_mu)
# Out:
# [ 2.71684358  1.34472509 -0.63365769  1.02608723  1.73888124  1.9754376
#   0.88114829  3.65942381  0.0107052   2.4062535  -1.20653023  1.53159795
#   1.93068114  3.96032132  0.54231799  3.71243248 -1.28696223  2.60409976
#   2.10402779  0.18242191  2.71266577  2.71100651 -0.47214338  2.0398753
#   0.97632857  0.53503262 -1.5627872  -1.98411    -0.51575534 -1.69172425
#   2.07299777  0.43534212  0.19479405  1.11094621  2.39082355  1.40293774
#   2.43726907 -0.90681405  0.01419987  1.56648021 -1.48270231 -0.67502597
#  -0.20184435  1.58614653  1.49718582 -0.17319645  1.83138484  4.45613393
#  -0.93694432  1.93382461  3.55447616 -0.29002249 -1.44250368  0.8988223
#  -1.02372679  0.90013841 -0.75943484 -0.91833803  0.37332539  2.82397984
#   1.76714317  2.17499686  8.07133963  2.32851405 -0.02374999  0.07347646
#   2.16281072  2.61574533 -0.59295161  0.26196702 -1.94032496  0.30544827
#   0.02801977 -0.90248956  1.8552339  -0.39976689 -0.85151332 -1.18404848
#   6.22614239 -1.58022051  1.98766345  0.12045702 -1.19289211  0.5818957
#   4.7543388   0.92316236  1.40854953  3.44012979  2.58064908  2.93933722
#   0.06352485  3.86178588 -0.10924066  2.43098576  2.62445785  2.07171211
#  -1.2090521   2.15015799  0.36287424  3.94164489 -1.50948111 -1.92828529
#   1.17986044 -0.04288594  1.56294901  2.13407241  6.01716456  1.50495372
#   6.04497167  2.3817266   2.1097914   2.93067322  4.74078434 -1.88529786
#   0.25545518  2.27596201 -1.51196462  1.55495111  0.47901417  2.43787659
#   0.77427493 -0.98418515  2.49889824 -1.1499305  -1.39259619 -0.15787579
#   5.27948969  0.40382235 -1.12501249  1.5829014   1.77587682  4.39045336
#   1.8735487   2.46922003  1.75881669  1.16362566 -0.02016873  3.25098079
#   2.24234814  4.07890089  1.79889181  0.92209311  0.80063593  4.17014956
#   0.14379784  2.00821682  1.77849851  2.62410513]

# %%
print(bcf_result[0])
# print(bcf_result[1])
# Out:
# [[-0.27231121 -0.15802242 -0.11514596 ... -0.15385393 -0.06573387
#   -0.13114827]
#  [-0.17577614 -0.15531792 -0.09444619 ... -0.23747505 -0.15955988
#   -0.17352617]
#  [-0.16653047 -0.23012336 -0.25865487 ... -0.20590028 -0.27744345
#   -0.26902721]
#  ...
#  [-0.27319769 -0.36103053 -0.35124076 ... -0.2103615  -0.1782664
#   -0.12743677]
#  [-0.02765818 -0.09676122 -0.19219316 ... -0.09315378 -0.07574765
#   -0.04070369]
#  [-0.07167381 -0.05160261 -0.12410957 ... -0.25437118 -0.15726972
#   -0.21938487]]
# [[-0.09582354 -0.06562958 -0.05420542 ... -0.09160685 -0.09223696
#   -0.09060468]
#  [-0.25889359 -0.22669395 -0.24389164 ... -0.26551635 -0.24873014
#   -0.27618366]
#  [-0.30419328 -0.31638303 -0.32902712 ... -0.35064426 -0.30758179
#   -0.34972707]
#  ...
#  [-0.123807   -0.13599675 -0.13079251 ... -0.21193768 -0.13826744
#   -0.13611861]
#  [-0.14821247 -0.16040223 -0.15397864 ... -0.13576621 -0.09270374
#   -0.08735229]
#  [-0.32061547 -0.33280522 -0.32138106 ... -0.27450819 -0.23144572
#   -0.22609427]]

# %%
print(mean_squared_error(np.mean(bcf_result[2], axis=1), y_test))
# Out:
# 4.45698205774403

# %%
print(mean_squared_error(np.zeros_like(y_test), y_test))
# Out:
# 4.3616648463025856
