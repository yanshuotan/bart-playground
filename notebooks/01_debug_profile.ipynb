# %%
import sys
import os
sys.path.append(os.path.dirname(os.getcwd()))

# %%
import numpy as np
import sys
from pyinstrument import Profiler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from bart_playground import *
import bartz
import arviz as az
# Out:
# INFO:arviz.preview:arviz_base not installed
# INFO:arviz.preview:arviz_stats not installed
# INFO:arviz.preview:arviz_plots not installed

# %%
proposal_probs = {"multi_grow": 0.25, "multi_prune": 0.25, "multi_change": 0.4, "multi_swap": 0.1}
#proposal_probs = {"multi_grow": 0.5, "multi_prune": 0.5}
generator = DataGenerator(n_samples=160, n_features=2, noise=0.1, random_seed=42)
X, y = generator.generate(scenario="piecewise_flat")
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
bart1 = DefaultBART(ndpost=50, nskip=20, n_trees=100)
bart1.fit(X_train, y_train)
# Out:
# Iterations: 100%|██████████| 70/70 [00:08<00:00,  7.80it/s]

# %%
from pyinstrument import Profiler

profiler = Profiler()
profiler.start()

bart = MultiBART(ndpost=50, nskip=20, n_trees=100, proposal_probs=proposal_probs, multi_tries=1)
bart.fit(X_train, y_train)

profiler.stop()
profiler.print()
# Out:
# Iterations: 100%|██████████| 70/70 [00:05<00:00, 11.74it/s]
#   _     ._   __/__   _ _  _  _ _/_   Recorded: 14:16:57  Samples:  5857
#  /_//_/// /_\ / //_// / //_'/ //     Duration: 5.968     CPU time: 5.891
# /   _/                      v5.0.1
#
# Profile at C:\Windows\Temp\ipykernel_23776\2353391020.py:4
#
# 5.970 <module>  C:\Windows\Temp\ipykernel_23776\2353391020.py:1
# └─ 5.970 MultiBART.fit  bart_playground\bart.py:27
#    └─ 5.969 MultiSampler.run  bart_playground\samplers.py:83
#       └─ 5.908 MultiSampler.one_iter  bart_playground\samplers.py:358
#          ├─ 5.228 MultiChange.propose  bart_playground\moves.py:33
#          │  ├─ 2.326 MultiChange.try_propose  bart_playground\moves.py:401
#          │  │  ├─ 1.038 Tree.change_split  bart_playground\params.py:391
#          │  │  │  └─ 1.015 Tree.update_n  bart_playground\params.py:405
#          │  │  │     ├─ 0.472 [self]  bart_playground\params.py
#          │  │  │     ├─ 0.272 Tree.update_n  bart_playground\params.py:405
#          │  │  │     └─ 0.232 sum  numpy\core\fromnumeric.py:2177
#          │  │  │           [2 frames hidden]  numpy, <built-in>
#          │  │  ├─ 0.288 BARTLikelihood.trees_log_marginal_lkhd  bart_playground\priors.py:279
#          │  │  │  ├─ 0.141 _trees_log_marginal_lkhd_numba  bart_playground\priors.py:27
#          │  │  │  └─ 0.066 Parameters.leaf_basis  bart_playground\params.py:675
#          │  │  ├─ 0.239 [self]  bart_playground\moves.py
#          │  │  ├─ 0.137 Parameters.copy  bart_playground\params.py:598
#          │  │  │  └─ 0.107 Tree.copy  bart_playground\params.py:157
#          │  │  │     └─ 0.101 Tree.from_existing  bart_playground\params.py:130
#          │  │  │        └─ 0.067 _copy_all_tree_arrays  bart_playground\params.py:43
#          │  │  ├─ 0.117 <listcomp>  bart_playground\moves.py:404
#          │  │  ├─ 0.093 Tree.copy  bart_playground\params.py:157
#          │  │  │  └─ 0.087 Tree.from_existing  bart_playground\params.py:130
#          │  │  ├─ 0.090 <listcomp>  bart_playground\moves.py:456
#          │  │  ├─ 0.079 Generator.choice  <built-in>
#          │  │  └─ 0.076 _mean  numpy\core\_methods.py:101
#          │  ├─ 1.277 MultiPrune.try_propose  bart_playground\moves.py:292
#          │  │  ├─ 0.404 Tree.split_leaf  bart_playground\params.py:269
#          │  │  │  ├─ 0.226 CPUDispatcher._compile_for_args  numba\core\dispatcher.py:344
#          │  │  │  │     [14 frames hidden]  numba
#          │  │  │  └─ 0.144 Tree._resize_arrays  bart_playground\params.py:206
#          │  │  │     └─ 0.079 full  numpy\core\numeric.py:274
#          │  │  ├─ 0.162 [self]  bart_playground\moves.py
#          │  │  ├─ 0.152 BARTLikelihood.trees_log_marginal_lkhd  bart_playground\priors.py:279
#          │  │  │  └─ 0.077 _trees_log_marginal_lkhd_numba  bart_playground\priors.py:27
#          │  │  ├─ 0.105 Parameters.copy  bart_playground\params.py:598
#          │  │  │  └─ 0.078 Tree.copy  bart_playground\params.py:157
#          │  │  │     └─ 0.074 Tree.from_existing  bart_playground\params.py:130
#          │  │  ├─ 0.081 <listcomp>  bart_playground\moves.py:335
#          │  │  └─ 0.071 Tree.prune_split  bart_playground\params.py:327
#          │  ├─ 1.124 MultiGrow.try_propose  bart_playground\moves.py:180
#          │  │  ├─ 0.178 [self]  bart_playground\moves.py
#          │  │  ├─ 0.177 BARTLikelihood.trees_log_marginal_lkhd  bart_playground\priors.py:279
#          │  │  │  └─ 0.092 _trees_log_marginal_lkhd_numba  bart_playground\priors.py:27
#          │  │  ├─ 0.163 Tree.split_leaf  bart_playground\params.py:269
#          │  │  │  └─ 0.102 Tree._resize_arrays  bart_playground\params.py:206
#          │  │  ├─ 0.122 <listcomp>  bart_playground\moves.py:183
#          │  │  ├─ 0.069 Generator.choice  <built-in>
#          │  │  └─ 0.061 Parameters.copy  bart_playground\params.py:598
#          │  ├─ 0.192 MultiSwap.try_propose  bart_playground\moves.py:513
#          │  │  └─ 0.107 Tree.swap_split  bart_playground\params.py:398
#          │  │     └─ 0.104 Tree.change_split  bart_playground\params.py:391
#          │  │        └─ 0.102 Tree.update_n  bart_playground\params.py:405
#          │  ├─ 0.137 Parameters.copy  bart_playground\params.py:598
#          │  │  └─ 0.096 Tree.copy  bart_playground\params.py:157
#          │  │     └─ 0.089 Tree.from_existing  bart_playground\params.py:130
#          │  └─ 0.128 [self]  bart_playground\moves.py
#          ├─ 0.231 Parameters.update_leaf_vals  bart_playground\params.py:689
#          │  ├─ 0.077 [self]  bart_playground\params.py
#          │  ├─ 0.076 Tree.update_outputs  bart_playground\params.py:440
#          │  └─ 0.061 Tree.n_leaves  bart_playground\params.py:464
#          ├─ 0.137 TreesPrior.resample_leaf_vals  bart_playground\priors.py:100
#          │  └─ 0.062 _resample_leaf_vals_numba  bart_playground\priors.py:13
#          ├─ 0.110 [self]  bart_playground\samplers.py
#          └─ 0.088 Parameters.copy  bart_playground\params.py:598
#             └─ 0.083 Tree.copy  bart_playground\params.py:157
#                └─ 0.081 Tree.from_existing  bart_playground\params.py:130
#                   └─ 0.061 _copy_all_tree_arrays  bart_playground\params.py:43

# %%
rf = RandomForestRegressor(random_state=42)
lr = LinearRegression()
rf.fit(X_train, y_train)
lr.fit(X_train, y_train)

btz = bartz.BART.gbart(np.transpose(X_train), y_train, ntree=100, ndpost=50, nskip=20)
btpred_all = btz.predict(np.transpose(X_test))
btpred = np.mean(np.array(btpred_all), axis=0)
# Out:
# INFO:2025-06-28 14:17:04,430:jax._src.xla_bridge:927: Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO:jax._src.xla_bridge:Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO:2025-06-28 14:17:04,437:jax._src.xla_bridge:927: Unable to initialize backend 'tpu': UNIMPLEMENTED: LoadPjrtPlugin is not implemented on windows yet.
# INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': UNIMPLEMENTED: LoadPjrtPlugin is not implemented on windows yet.

# %%
profiler = Profiler()
profiler.start()

default_proposal_probs = {"grow": 0.25, "prune": 0.25, "change": 0.4, "swap": 0.1}
bart_default = DefaultBART(ndpost=50, nskip=20, n_trees=100, proposal_probs=default_proposal_probs)
bart_default.fit(X_train, y_train)

profiler.stop()
profiler.print()
# Out:
# Iterations: 100%|██████████| 70/70 [00:03<00:00, 23.06it/s]
#   _     ._   __/__   _ _  _  _ _/_   Recorded: 14:17:12  Samples:  3015
#  /_//_/// /_\ / //_// / //_'/ //     Duration: 3.045     CPU time: 3.031
# /   _/                      v5.0.1
#
# Profile at C:\Windows\Temp\ipykernel_23776\3672608610.py:2
#
# 3.044 ZMQInteractiveShell.run_code  IPython\core\interactiveshell.py:3543
# └─ 3.043 <module>  C:\Windows\Temp\ipykernel_23776\3672608610.py:1
#    └─ 3.043 DefaultBART.fit  bart_playground\bart.py:27
#       └─ 3.042 DefaultSampler.run  bart_playground\samplers.py:83
#          └─ 3.004 DefaultSampler.one_iter  bart_playground\samplers.py:280
#             ├─ 1.988 Swap.propose  bart_playground\moves.py:33
#             │  ├─ 1.014 Swap.try_propose  bart_playground\moves.py:146
#             │  │  ├─ 0.861 Tree.swap_split  bart_playground\params.py:398
#             │  │  │  └─ 0.843 Tree.change_split  bart_playground\params.py:391
#             │  │  │     └─ 0.831 Tree.update_n  bart_playground\params.py:405
#             │  │  │        ├─ 0.417 Tree.update_n  bart_playground\params.py:405
#             │  │  │        │  ├─ 0.249 [self]  bart_playground\params.py
#             │  │  │        │  ├─ 0.099 sum  numpy\core\fromnumeric.py:2177
#             │  │  │        │  │     [2 frames hidden]  numpy, <built-in>
#             │  │  │        │  └─ 0.050 Tree.update_n  bart_playground\params.py:405
#             │  │  │        ├─ 0.287 [self]  bart_playground\params.py
#             │  │  │        └─ 0.106 sum  numpy\core\fromnumeric.py:2177
#             │  │  │              [2 frames hidden]  numpy, <built-in>
#             │  │  ├─ 0.086 Tree.nonterminal_split_nodes  bart_playground\params.py:476
#             │  │  │  └─ 0.075 <listcomp>  bart_playground\params.py:478
#             │  │  └─ 0.035 Generator.integers  <built-in>
#             │  ├─ 0.319 Parameters.copy  bart_playground\params.py:598
#             │  │  ├─ 0.256 Tree.copy  bart_playground\params.py:157
#             │  │  │  └─ 0.241 Tree.from_existing  bart_playground\params.py:130
#             │  │  │     ├─ 0.153 _copy_all_tree_arrays  bart_playground\params.py:43
#             │  │  │     │  ├─ 0.118 [self]  bart_playground\params.py
#             │  │  │     │  └─ 0.035 _numba_unpickle  numba\core\serialize.py:30
#             │  │  │     └─ 0.074 [self]  bart_playground\params.py
#             │  │  └─ 0.033 [self]  bart_playground\params.py
#             │  ├─ 0.287 Change.try_propose  bart_playground\moves.py:124
#             │  │  └─ 0.216 Tree.change_split  bart_playground\params.py:391
#             │  │     └─ 0.210 Tree.update_n  bart_playground\params.py:405
#             │  │        ├─ 0.089 [self]  bart_playground\params.py
#             │  │        ├─ 0.062 Tree.update_n  bart_playground\params.py:405
#             │  │        └─ 0.048 sum  numpy\core\fromnumeric.py:2177
#             │  │           └─ 0.039 _wrapreduction  numpy\core\fromnumeric.py:71
#             │  ├─ 0.205 Grow.try_propose  bart_playground\moves.py:76
#             │  │  ├─ 0.082 Tree.split_leaf  bart_playground\params.py:269
#             │  │  │  └─ 0.047 Tree._resize_arrays  bart_playground\params.py:206
#             │  │  ├─ 0.031 fast_choice  bart_playground\util.py:9
#             │  │  └─ 0.031 Tree.terminal_split_nodes  bart_playground\params.py:472
#             │  └─ 0.098 Prune.try_propose  bart_playground\moves.py:100
#             │     └─ 0.052 Tree.prune_split  bart_playground\params.py:327
#             │        └─ 0.031 Tree._truncate_tree_arrays  bart_playground\params.py:249
#             ├─ 0.469 DefaultSampler.log_mh_ratio  bart_playground\samplers.py:273
#             │  ├─ 0.362 BARTLikelihood.trees_log_marginal_lkhd_ratio  bart_playground\priors.py:320
#             │  │  └─ 0.344 BARTLikelihood.trees_log_marginal_lkhd  bart_playground\priors.py:279
#             │  │     ├─ 0.189 _trees_log_marginal_lkhd_numba  bart_playground\priors.py:27
#             │  │     ├─ 0.067 Parameters.leaf_basis  bart_playground\params.py:675
#             │  │     │  └─ 0.061 Tree.leaf_basis  bart_playground\params.py:481
#             │  │     │     └─ 0.043 _compute_leaf_basis  bart_playground\params.py:7
#             │  │     ├─ 0.050 [self]  bart_playground\priors.py
#             │  │     └─ 0.038 Parameters.evaluate  bart_playground\params.py:637
#             │  ├─ 0.056 TreesPrior.trees_log_prior_ratio  bart_playground\priors.py:155
#             │  │  └─ 0.051 TreesPrior.trees_log_prior  bart_playground\priors.py:132
#             │  └─ 0.051 [self]  bart_playground\samplers.py
#             ├─ 0.179 Parameters.update_leaf_vals  bart_playground\params.py:689
#             │  ├─ 0.064 [self]  bart_playground\params.py
#             │  ├─ 0.063 Tree.update_outputs  bart_playground\params.py:440
#             │  └─ 0.035 Tree.n_leaves  bart_playground\params.py:464
#             ├─ 0.088 TreesPrior.resample_leaf_vals  bart_playground\priors.py:100
#             │  └─ 0.037 _resample_leaf_vals_numba  bart_playground\priors.py:13
#             ├─ 0.087 Parameters.copy  bart_playground\params.py:598
#             │  └─ 0.085 Tree.copy  bart_playground\params.py:157
#             │     └─ 0.084 Tree.from_existing  bart_playground\params.py:130
#             │        ├─ 0.049 _copy_all_tree_arrays  bart_playground\params.py:43
#             │        └─ 0.035 [self]  bart_playground\params.py
#             ├─ 0.085 [self]  bart_playground\samplers.py
#             └─ 0.031 Generator.uniform  <built-in>

# %%
models = {"bart" : bart, 
          "rf" : rf, 
          "lr" : lr,
          "btz" : btz,
          "bart_default" : bart_default}
results = {}
for model_name, model in models.items():
    if model_name == "btz":
        results[model_name] = mean_squared_error(y_test, btpred)
    else:
        results[model_name] = mean_squared_error(y_test, model.predict(X_test))
results
# Out:
# {'bart': 0.02112037030574617,
#  'rf': 0.022139023845392215,
#  'lr': 0.048045521328019404,
#  'btz': 0.022409798535525886,
#  'bart_default': 0.02292141162635982}
