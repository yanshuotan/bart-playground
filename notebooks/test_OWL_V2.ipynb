# %% [markdown]
# ## Test Probit OWL BART

# %%
import sys
import os
sys.path.append(os.path.dirname(os.getcwd()))

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss, accuracy_score, roc_auc_score
from sklearn.calibration import calibration_curve
# from bart_playground import *
from bart_playground.bart import DefaultBART, ProbitBART, OWLBART, ProbitOWLBART
#, temp #, OWLBART
# from bart_playground.priors import OWLPrior

# %%
# Parameters
N_TREES = 50
NDPOST = 1000
NSKIP = 200
RANDOM_STATE = 42

# If debug then run with only one dataset and record running time
# Otherwise run with all datasets
debug = False

# %%
def simulate_data(n=30, seed=1):
    np.random.seed(seed)
    X = np.random.uniform(-1, 1, size=(n, 50))
    A = np.random.choice([-1, 1], size=n)
    base = 1 + 2*X[:, 0] + X[:, 1] + 0.5*X[:, 2]
    
    # Scenario 1
    T1 = 0.442 * (1 - X[:, 0] - X[:, 1]) * A
    mu1 = base + T1
    R1 = np.random.normal(loc=mu1, scale=1)

    # Scenario 2
    T2 = (X[:, 1] - 0.25 * (X[:, 0])**2 - 1) * A
    mu2 = base + T2
    R2 = np.random.normal(loc=mu2, scale=1)

    # Scenario 3
    T3 = (0.5 - (X[:, 0])**2 - (X[:, 1])**2) * ((X[:, 0])**2 + (X[:, 1])**2 - 0.3) * A
    mu3 = base + T3
    R3 = np.random.normal(loc=mu3, scale=1)

    # Scenario 4
    T4 = (1 - (X[:, 0])**3 + np.exp((X[:, 2])**2 + X[:, 4]) + 0.6 * X[:, 5] - (X[:, 6] + X[:, 7])**2) * A
    mu4 = base + T4
    R4 = np.random.normal(loc=mu4, scale=1)
    
    # Convert to DataFrames
    colnames = [f"X{i+1}" for i in range(50)]
    base_df = pd.DataFrame(X, columns=colnames)
    base_df["A"] = A

    df1 = base_df.copy()
    df1["R"] = R1

    df2 = base_df.copy()
    df2["R"] = R2

    df3 = base_df.copy()
    df3["R"] = R3

    df4 = base_df.copy()
    df4["R"] = R4

    return {"Scenario 1": df1, "Scenario 2": df2, "Scenario 3": df3, "Scenario 4": df4}

# Print first 5 rows of each scenario
simulated = simulate_data(n=30)
for name, df in simulated.items():
    print(f"\n{name} (first 5 rows):")
    print(df.head())
# Out:
# Scenario 1 (first 5 rows):
#          X1        X2        X3        X4        X5        X6        X7  \
# 0 -0.165956  0.440649 -0.999771 -0.395335 -0.706488 -0.815323 -0.627480
# 1 -0.961266  0.357671 -0.576744 -0.468907 -0.016854 -0.893275  0.148235
# 2 -0.346710  0.054116  0.771884 -0.285460  0.817070  0.246720 -0.968358
# 3 -0.856051  0.934553  0.136201 -0.593414 -0.495349  0.487652 -0.609141
# 4  0.900352  0.113306  0.831213  0.283132 -0.219985 -0.028019  0.208621
#
#          X8        X9       X10  ...       X43       X44       X45       X46  \
# 0 -0.308879 -0.206465  0.077633  ... -0.439112  0.578559 -0.793548 -0.104213
# 1 -0.706543  0.178611  0.399517  ... -0.100176  0.156779 -0.183726 -0.525946
# 2  0.858874  0.381794  0.994646  ... -0.880165 -0.757313 -0.910896 -0.785012
# 3  0.162718  0.940040  0.693658  ...  0.470132  0.544356  0.815632  0.863944
# 4  0.099096  0.852363  0.837467  ...  0.155714 -0.631980  0.575858  0.224062
#
#         X47       X48       X49       X50  A         R
# 0  0.817191 -0.412772 -0.424449 -0.739943  1  0.594654
# 1  0.806759  0.147359 -0.994259  0.234290  1  0.472799
# 2 -0.548581  0.425978  0.119434 -0.974888 -1 -1.044436
# 3 -0.972097 -0.531276  0.233557  0.898033 -1 -2.611385
# 4 -0.892181 -0.159613  0.358138  0.837204 -1  2.290367
#
# [5 rows x 52 columns]
#
# Scenario 2 (first 5 rows):
#          X1        X2        X3        X4        X5        X6        X7  \
# 0 -0.165956  0.440649 -0.999771 -0.395335 -0.706488 -0.815323 -0.627480
# 1 -0.961266  0.357671 -0.576744 -0.468907 -0.016854 -0.893275  0.148235
# 2 -0.346710  0.054116  0.771884 -0.285460  0.817070  0.246720 -0.968358
# 3 -0.856051  0.934553  0.136201 -0.593414 -0.495349  0.487652 -0.609141
# 4  0.900352  0.113306  0.831213  0.283132 -0.219985 -0.028019  0.208621
#
#          X8        X9       X10  ...       X43       X44       X45       X46  \
# 0 -0.308879 -0.206465  0.077633  ... -0.439112  0.578559 -0.793548 -0.104213
# 1 -0.706543  0.178611  0.399517  ... -0.100176  0.156779 -0.183726 -0.525946
# 2  0.858874  0.381794  0.994646  ... -0.880165 -0.757313 -0.910896 -0.785012
# 3  0.162718  0.940040  0.693658  ...  0.470132  0.544356  0.815632  0.863944
# 4  0.099096  0.852363  0.837467  ...  0.155714 -0.631980  0.575858  0.224062
#
#         X47       X48       X49       X50  A         R
# 0  0.817191 -0.412772 -0.424449 -0.739943  1 -0.509396
# 1  0.806759  0.147359 -0.994259  0.234290  1 -0.904560
# 2 -0.548581  0.425978  0.119434 -0.974888 -1  0.850594
# 3 -0.972097 -0.531276  0.233557  0.898033 -1  1.417468
# 4 -0.892181 -0.159613  0.358138  0.837204 -1  4.969075
#
# [5 rows x 52 columns]
#
# Scenario 3 (first 5 rows):
#          X1        X2        X3        X4        X5        X6        X7  \
# 0 -0.165956  0.440649 -0.999771 -0.395335 -0.706488 -0.815323 -0.627480
# 1 -0.961266  0.357671 -0.576744 -0.468907 -0.016854 -0.893275  0.148235
# 2 -0.346710  0.054116  0.771884 -0.285460  0.817070  0.246720 -0.968358
# 3 -0.856051  0.934553  0.136201 -0.593414 -0.495349  0.487652 -0.609141
# 4  0.900352  0.113306  0.831213  0.283132 -0.219985 -0.028019  0.208621
#
#          X8        X9       X10  ...       X43       X44       X45       X46  \
# 0 -0.308879 -0.206465  0.077633  ... -0.439112  0.578559 -0.793548 -0.104213
# 1 -0.706543  0.178611  0.399517  ... -0.100176  0.156779 -0.183726 -0.525946
# 2  0.858874  0.381794  0.994646  ... -0.880165 -0.757313 -0.910896 -0.785012
# 3  0.162718  0.940040  0.693658  ...  0.470132  0.544356  0.815632  0.863944
# 4  0.099096  0.852363  0.837467  ...  0.155714 -0.631980  0.575858  0.224062
#
#         X47       X48       X49       X50  A         R
# 0  0.817191 -0.412772 -0.424449 -0.739943  1  0.231816
# 1  0.806759  0.147359 -0.994259  0.234290  1 -0.882638
# 2 -0.548581  0.425978  0.119434 -0.974888 -1  0.442401
# 3 -0.972097 -0.531276  0.233557  0.898033 -1  2.709411
# 4 -0.892181 -0.159613  0.358138  0.837204 -1  2.131089
#
# [5 rows x 52 columns]
#
# Scenario 4 (first 5 rows):
#          X1        X2        X3        X4        X5        X6        X7  \
# 0 -0.165956  0.440649 -0.999771 -0.395335 -0.706488 -0.815323 -0.627480
# 1 -0.961266  0.357671 -0.576744 -0.468907 -0.016854 -0.893275  0.148235
# 2 -0.346710  0.054116  0.771884 -0.285460  0.817070  0.246720 -0.968358
# 3 -0.856051  0.934553  0.136201 -0.593414 -0.495349  0.487652 -0.609141
# 4  0.900352  0.113306  0.831213  0.283132 -0.219985 -0.028019  0.208621
#
#          X8        X9       X10  ...       X43       X44       X45       X46  \
# 0 -0.308879 -0.206465  0.077633  ... -0.439112  0.578559 -0.793548 -0.104213
# 1 -0.706543  0.178611  0.399517  ... -0.100176  0.156779 -0.183726 -0.525946
# 2  0.858874  0.381794  0.994646  ... -0.880165 -0.757313 -0.910896 -0.785012
# 3  0.162718  0.940040  0.693658  ...  0.470132  0.544356  0.815632  0.863944
# 4  0.099096  0.852363  0.837467  ...  0.155714 -0.631980  0.575858  0.224062
#
#         X47       X48       X49       X50  A         R
# 0  0.817191 -0.412772 -0.424449 -0.739943  1  1.665199
# 1  0.806759  0.147359 -0.994259  0.234290  1  2.204196
# 2 -0.548581  0.425978  0.119434 -0.974888 -1 -4.090360
# 3 -0.972097 -0.531276  0.233557  0.898033 -1 -1.279380
# 4 -0.892181 -0.159613  0.358138  0.837204 -1  1.261840
#
# [5 rows x 52 columns]

# %%
from bart_playground.bart import ProbitOWLBART


df = simulated["Scenario 1"]
X = df[[col for col in df.columns if col.startswith("X")]].values
A = df["A"].values
R = df["R"].values

X_train, X_test, A_train, A_test, R_train, R_test = train_test_split(
    X, A, R, test_size=0.3, random_state=42
)

owlbart = ProbitOWLBART(n_trees=50, ndpost=1000, nskip=200, random_state=42,
                  treatment=A_train, reward=R_train
)
owlbart.fit(X_train, A_train)
A_opt = owlbart.predict_optimal_treatment(X_test)
R_pred = owlbart.predict_outcome(X_test, A_opt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 13
#       7 R = df["R"].values
#       9 X_train, X_test, A_train, A_test, R_train, R_test = train_test_split(
#      10     X, A, R, test_size=0.3, random_state=42
#      11 )
# ---> 13 owlbart = ProbitOWLBART(n_trees=50, ndpost=1000, nskip=200, random_state=42,
#      14                   treatment=A_train, reward=R_train
#      15 )
#      16 owlbart.fit(X_train, A_train)
#      17 A_opt = owlbart.predict_optimal_treatment(X_test)
#
# File ~/Desktop/bart-playground-master-2/bart_playground/bart.py:425, in ProbitOWLBART.__init__(self, ndpost, nskip, n_trees, tree_alpha, tree_beta, c, d, proposal_probs, tol, max_bins, random_state, temperature, treatment, reward)
#     423 preprocessor = ClassificationPreprocessor(max_bins=max_bins)
#     424 rng = np.random.default_rng(random_state)
# --> 425 prior = ProbitOWLPrior(n_trees, tree_alpha, tree_beta, c, d, treatment, reward, rng)
#     426 temp_schedule = self._check_temperature(temperature)
#     427 sampler = ProbitSampler(prior=prior, proposal_probs=proposal_probs,
#     428                        generator=rng, tol=tol, temp_schedule=temp_schedule)
#
# File ~/Desktop/bart-playground-master-2/bart_playground/priors.py:634, in ProbitOWLPrior.__init__(self, n_trees, tree_alpha, tree_beta, c, d, treatment, reward, generator)
#     631     c = n_trees/(a0 ** 2) + 0.5
#     632     d = n_trees/(a0 ** 2)
# --> 634 self.tree_prior = ProbitPrior(n_trees, tree_alpha, tree_beta, c, d, generator, parent=self)
#     635 self.likelihood = OWLLikelihood(c, d, parent=self, treatment=None, reward=None)
#     637 # Placeholders for values reused in resampling
#
# TypeError: ProbitPrior.__init__() got an unexpected keyword argument 'parent'
