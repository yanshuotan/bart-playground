# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
from pyinstrument import Profiler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import os
sys.path.append(os.path.dirname(os.getcwd()))
from bart_playground import *

import bartz

# %% [markdown]
# # Birth & Death

# %%
proposal_probs = {"grow" : 0.5, "prune" : 0.5}
special_probs = {"birth": 0.5, "death": 0.5}
#special_probs = {"birth": 0.25, "death": 0.25, "break": 0.25, "combine": 0.25}
generator = DataGenerator(n_samples=160, n_features=2, noise=0.1, random_seed=42)
X, y = generator.generate(scenario="piecewise_flat")
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
scatter = plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis', edgecolor='k', alpha=0.7)
plt.colorbar(scatter, label='Target Value (y)')
plt.title('Relationship Between Features and Target')
plt.xlabel('Feature 1 (X[:, 0])')
plt.ylabel('Feature 2 (X[:, 1])')
plt.grid(True)
plt.show()

# %%
bart = ChangeNumTreeBART(ndpost=10000, nskip=0, n_trees=100, 
                         proposal_probs=proposal_probs, special_probs = special_probs, 
                         theta_0 = 100, theta_df = np.inf, 
                         tree_num_prior_type="poisson")
bart.fit(X_train, y_train)
# Out:
# Iterations: 100%|██████████| 10000/10000 [03:17<00:00, 50.62it/s]

# %%
bart.trace[-1].n_trees
# Out:
# 95

# %%
bart.trace[-1].global_params
# Out:
# {'eps_sigma2': array([0.37996108]), 'ntree_theta': 100}

# %%
# Extract the n_trees value for each instance
n_trees_list = [instance.n_trees for instance in bart.trace]
np.mean(n_trees_list)
# Out:
# 96.81231876812319

# %%
# Create a histogram with bins for each integer value
plt.figure(figsize=(10, 6))
plt.hist(n_trees_list, bins=20, edgecolor='k', alpha=0.7)
plt.title('Distribution of n_trees in the sampling period')
plt.xlabel('Number of Trees (n_trees)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Create a line plot
plt.figure(figsize=(10, 6))
plt.plot(
    range(len(n_trees_list)), 
    n_trees_list, 
    marker='o', 
    markersize=2,  # Adjust marker size
    linestyle='-', 
    linewidth=0.5,  # Adjust line width
    color='b'
)
plt.title('Change in n_trees over the sampling period')
plt.xlabel('Iteration')
plt.ylabel('Number of Trees (n_trees)')
plt.grid(True)
plt.show()

# %%
print(f'Birth move count: {len(bart.sampler.birth_mh_ratios)}; median: {np.median(bart.sampler.birth_mh_ratios)}')
# Out:
# Birth move count: 5035; median: 0.05102040816326629

# %%
print(f'Death move count: {len(bart.sampler.death_mh_ratios)}; median: {np.median(bart.sampler.death_mh_ratios)}')
# Out:
# Death move count: 263; median: 19.59999999999962

# %%
ntree = bart.trace[-1].n_trees
rf = RandomForestRegressor(n_estimators=ntree)
lr = LinearRegression()
rf.fit(X_train, y_train)
lr.fit(X_train, y_train)

btz = bartz.BART.gbart(np.transpose(X_train), y_train, ntree=ntree, ndpost=200, nskip=100)
btpred_all = btz.predict(np.transpose(X_test))
btpred = np.mean(np.array(btpred_all), axis=0)
# Out:
# INFO:2025-04-15 20:06:47,591:jax._src.xla_bridge:927: Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO:jax._src.xla_bridge:Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO:2025-04-15 20:06:47,598:jax._src.xla_bridge:927: Unable to initialize backend 'tpu': UNIMPLEMENTED: LoadPjrtPlugin is not implemented on windows yet.
# INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': UNIMPLEMENTED: LoadPjrtPlugin is not implemented on windows yet.
# Iteration 100/300 P_grow=0.57 P_prune=0.43 A_grow=0.31 A_prune=0.37 (burnin)
# Iteration 200/300 P_grow=0.57 P_prune=0.43 A_grow=0.30 A_prune=0.41
# Iteration 300/300 P_grow=0.60 P_prune=0.40 A_grow=0.39 A_prune=0.47

# %%
models = {"bart" : bart, 
          "rf" : rf, 
          "lr" : lr,
          "btz" : btz}
results = {}
for model_name, model in models.items():
    if model_name == "btz":
        results[model_name] = mean_squared_error(y_test, btpred)
    else:
        results[model_name] = mean_squared_error(y_test, model.predict(X_test))
results
# Out:
# {'bart': 0.16639671305669354,
#  'rf': 0.02105110203093554,
#  'lr': 0.048045521328019404,
#  'btz': 0.023979007375326444}

# %%
bart.trace[-1].trees
# Out:
# [Tree(vars=[ 1  0 -1 -1 -1 -2 -2 -2], thresholds=[0.82685667 0.93321272        nan        nan        nan        nan
#          nan        nan], leaf_vals=[        nan         nan  0.03848105 -0.00975561 -0.01736787         nan
#           nan         nan], n_vals=[120 103  17  98   5  -2  -2  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.04226988        nan        nan        nan], leaf_vals=[        nan -0.00547228  0.03586365         nan], n_vals=[120   5 115  -2]),
#  Tree(vars=[ 0 -1  1 -2 -2 -1 -1 -2], thresholds=[0.69029431        nan 0.1162583         nan        nan        nan
#          nan        nan], leaf_vals=[        nan -0.0130168          nan         nan         nan -0.02861978
#    0.00369469         nan], n_vals=[120  85  35  -2  -2   2  33  -2]),
#  Tree(vars=[ 0 -1  1 -2 -2 -1 -1 -2], thresholds=[0.69029431        nan 0.57122029        nan        nan        nan
#          nan        nan], leaf_vals=[        nan -0.04561569         nan         nan         nan  0.05190232
#    0.04838423         nan], n_vals=[120  85  35  -2  -2  14  21  -2]),
#  Tree(vars=[ 0  0 -1 -1  1 -2 -2 -2 -2 -1 -1 -2 -2 -2 -2 -2], thresholds=[0.36987285 0.04302845        nan        nan 0.51179255        nan
#          nan        nan        nan        nan        nan        nan
#          nan        nan        nan        nan], leaf_vals=[        nan         nan  0.07074316 -0.05683853         nan         nan
#           nan         nan         nan  0.01921967  0.02816968         nan
#           nan         nan         nan         nan], n_vals=[120  49  71   5  44  -2  -2  -2  -2  21  23  -2  -2  -2  -2  -2]),
#  Tree(vars=[ 0 -1  1 -2 -2  0  1 -2 -2 -2 -2 -1 -1 -1 -1 -2], thresholds=[0.06102726        nan 0.05362162        nan        nan 0.66302364
#   0.09776566        nan        nan        nan        nan        nan
#          nan        nan        nan        nan], leaf_vals=[        nan  0.00807949         nan         nan         nan         nan
#           nan         nan         nan         nan         nan -0.03555197
#    0.02025736  0.03021389  0.0209288          nan], n_vals=[120   9 111  -2  -2   8 103  -2  -2  -2  -2   7   1   3 100  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.7461699       nan       nan       nan], leaf_vals=[        nan  0.00389311 -0.01693975         nan], n_vals=[120  89  31  -2]),
#  Tree(vars=[ 0  1 -1 -1  0 -2 -2 -2 -2 -1 -1 -2 -2 -2 -2 -2], thresholds=[0.78379671 0.43650068        nan        nan 0.10781608        nan
#          nan        nan        nan        nan        nan        nan
#          nan        nan        nan        nan], leaf_vals=[        nan         nan -0.01098505 -0.01203407         nan         nan
#           nan         nan         nan  0.00259712  0.01463462         nan
#           nan         nan         nan         nan], n_vals=[120  98  22  43  55  -2  -2  -2  -2   7  48  -2  -2  -2  -2  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.22963186        nan        nan        nan], leaf_vals=[       nan 0.02559525 0.02481882        nan], n_vals=[120  25  95  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.13700382        nan        nan        nan], leaf_vals=[        nan -0.04468888  0.03130957         nan], n_vals=[120  16 104  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.51999857        nan        nan        nan], leaf_vals=[       nan 0.00783374 0.042599          nan], n_vals=[120  62  58  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.13700382        nan        nan        nan], leaf_vals=[        nan -0.02406954  0.01810698         nan], n_vals=[120  16 104  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.96070553        nan        nan        nan], leaf_vals=[       nan 0.0417475  0.02243246        nan], n_vals=[120 118   2  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.12114224        nan        nan        nan], leaf_vals=[        nan -0.0380545   0.02434803         nan], n_vals=[120  17 103  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.8564048       nan       nan       nan], leaf_vals=[        nan -0.03674354  0.02520373         nan], n_vals=[120 105  15  -2]),
#  Tree(vars=[ 1 -1  0 -2 -2 -1 -1 -2], thresholds=[0.18636191        nan 0.23392766        nan        nan        nan
#          nan        nan], leaf_vals=[        nan  0.01583129         nan         nan         nan -0.03736728
#    0.0276142          nan], n_vals=[120  23  97  -2  -2  27  70  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.92899185        nan        nan        nan], leaf_vals=[        nan  0.00398988 -0.01076944         nan], n_vals=[120 115   5  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.78617183        nan        nan        nan], leaf_vals=[       nan 0.00890743 0.01684162        nan], n_vals=[120  95  25  -2]),
#  Tree(vars=[-1 -2], thresholds=[nan nan], leaf_vals=[0.00746792        nan], n_vals=[120  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.774004      nan      nan      nan], leaf_vals=[        nan -0.03783853  0.02761989         nan], n_vals=[120  95  25  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.66923384        nan        nan        nan], leaf_vals=[        nan -0.04653181  0.01049059         nan], n_vals=[120  84  36  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.78379671        nan        nan        nan], leaf_vals=[       nan 0.05535547 0.00883972        nan], n_vals=[120  98  22  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.11667251        nan        nan        nan], leaf_vals=[        nan -0.01738047  0.07841659         nan], n_vals=[120  16 104  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.23257914        nan        nan        nan], leaf_vals=[        nan -0.0351819   0.03813451         nan], n_vals=[120  33  87  -2]),
#  Tree(vars=[ 0  1 -1 -1 -1 -2 -2 -2], thresholds=[0.29952342 0.59477153        nan        nan        nan        nan
#          nan        nan], leaf_vals=[        nan         nan  0.06069854 -0.01598386  0.05372913         nan
#           nan         nan], n_vals=[120  42  78  26  16  -2  -2  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.37842875        nan        nan        nan], leaf_vals=[       nan  0.0011066 -0.0201284        nan], n_vals=[120  42  78  -2]),
#  Tree(vars=[ 0 -1  1 -2 -2  0 -1 -2 -2 -2 -2 -1 -1 -2 -2 -2], thresholds=[0.38148923        nan 0.1061896         nan        nan 0.77005534
#          nan        nan        nan        nan        nan        nan
#          nan        nan        nan        nan], leaf_vals=[        nan  0.00354085         nan         nan         nan         nan
#    0.0118618          nan         nan         nan         nan  0.02901557
#   -0.00237116         nan         nan         nan], n_vals=[120  53  67  -2  -2   8  59  -2  -2  -2  -2   6   2  -2  -2  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.75827773        nan        nan        nan], leaf_vals=[       nan 0.04051709 0.01397631        nan], n_vals=[120  91  29  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.7347679       nan       nan       nan], leaf_vals=[        nan -0.02643016  0.02237005         nan], n_vals=[120  90  30  -2]),
#  Tree(vars=[ 1  0  1  1 -1 -1  1 -1 -1 -2 -2 -2 -2 -1 -1 -2], thresholds=[0.32622325 0.78379671 0.39784245 0.2435121         nan        nan
#   0.92357691        nan        nan        nan        nan        nan
#          nan        nan        nan        nan], leaf_vals=[        nan         nan         nan         nan -0.0181386  -0.00323202
#           nan -0.01252477  0.03288816         nan         nan         nan
#           nan  0.02535963  0.00137059         nan], n_vals=[120  37  83  31   6   8  75  22   9  -2  -2  -2  -2  67   8  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.02206496        nan        nan        nan], leaf_vals=[        nan -0.01490304 -0.04657879         nan], n_vals=[120   3 117  -2]),
#  Tree(vars=[ 1 -1  1 -2 -2 -1 -1 -2], thresholds=[0.85612084        nan 0.95305243        nan        nan        nan
#          nan        nan], leaf_vals=[        nan -0.04621483         nan         nan         nan  0.04378626
#   -0.04505775         nan], n_vals=[120 106  14  -2  -2  11   3  -2]),
#  Tree(vars=[ 0  0 -1 -1 -1 -2 -2 -2], thresholds=[0.63437644 0.0191711         nan        nan        nan        nan
#          nan        nan], leaf_vals=[        nan         nan -0.02560175 -0.01420546 -0.01068758         nan
#           nan         nan], n_vals=[120  79  41   2  77  -2  -2  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.46836     nan     nan     nan], leaf_vals=[        nan -0.017843    0.06916293         nan], n_vals=[120  66  54  -2]),
#  Tree(vars=[-1 -2], thresholds=[nan nan], leaf_vals=[0.00898791        nan], n_vals=[120  -2]),
#  Tree(vars=[ 0  1 -1 -1 -1 -2 -2 -2], thresholds=[0.65128575 0.37842875        nan        nan        nan        nan
#          nan        nan], leaf_vals=[        nan         nan -0.02706348 -0.01530686  0.02041732         nan
#           nan         nan], n_vals=[120  81  39  33  48  -2  -2  -2]),
#  Tree(vars=[ 1 -1  0 -2 -2 -1 -1 -2], thresholds=[0.58778035        nan 0.55914191        nan        nan        nan
#          nan        nan], leaf_vals=[        nan -0.01362136         nan         nan         nan -0.01003246
#    0.00132296         nan], n_vals=[120  70  50  -2  -2  26  24  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.89767213        nan        nan        nan], leaf_vals=[        nan -0.00673272 -0.01461628         nan], n_vals=[120 110  10  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.44478524        nan        nan        nan], leaf_vals=[        nan -0.03003243  0.00654459         nan], n_vals=[120  60  60  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.49617755        nan        nan        nan], leaf_vals=[        nan  0.01340992 -0.00025359         nan], n_vals=[120  59  61  -2]),
#  Tree(vars=[ 0 -1  0 -2 -2 -1 -1 -2], thresholds=[0.21091556        nan 0.38640338        nan        nan        nan
#          nan        nan], leaf_vals=[        nan -0.05274808         nan         nan         nan -0.00273905
#    0.02503719         nan], n_vals=[120  30  90  -2  -2  24  66  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.59333154        nan        nan        nan], leaf_vals=[        nan  0.01590646 -0.03209043         nan], n_vals=[120  77  43  -2]),
#  Tree(vars=[ 1  1 -1 -1 -1 -2 -2 -2], thresholds=[0.80811199 0.78272561        nan        nan        nan        nan
#          nan        nan], leaf_vals=[        nan         nan -0.00724615  0.004738    0.05345743         nan
#           nan         nan], n_vals=[120 100  20  92   8  -2  -2  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.78460771        nan        nan        nan], leaf_vals=[        nan  0.01063293 -0.00101251         nan], n_vals=[120  93  27  -2]),
#  Tree(vars=[ 0  1 -1 -1 -1 -2 -2 -2], thresholds=[0.8077883  0.67619566        nan        nan        nan        nan
#          nan        nan], leaf_vals=[        nan         nan -0.00206996  0.01828425  0.04794411         nan
#           nan         nan], n_vals=[120  99  21  69  30  -2  -2  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.31136559        nan        nan        nan], leaf_vals=[        nan -0.04492265  0.03765786         nan], n_vals=[120  35  85  -2]),
#  Tree(vars=[ 0  0 -1 -1 -1 -2 -2 -2], thresholds=[0.774004   0.44836788        nan        nan        nan        nan
#          nan        nan], leaf_vals=[       nan        nan 0.00578851 0.02973303 0.04379079        nan
#          nan        nan], n_vals=[120  95  25  61  34  -2  -2  -2]),
#  Tree(vars=[ 0  0 -1 -1 -1 -2 -2 -2], thresholds=[0.89657926 0.55655262        nan        nan        nan        nan
#          nan        nan], leaf_vals=[        nan         nan -0.01322261 -0.01661423 -0.00196432         nan
#           nan         nan], n_vals=[120 109  11  74  35  -2  -2  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.29510381        nan        nan        nan], leaf_vals=[        nan -0.06941113  0.03094473         nan], n_vals=[120  41  79  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.29164034        nan        nan        nan], leaf_vals=[        nan -0.0300313   0.01076768         nan], n_vals=[120  40  80  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.22927623        nan        nan        nan], leaf_vals=[        nan -0.05384638  0.01590199         nan], n_vals=[120  31  89  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.10781608        nan        nan        nan], leaf_vals=[        nan -0.03816572 -0.03769853         nan], n_vals=[120  14 106  -2]),
#  Tree(vars=[ 0 -1  1 -2 -2 -1 -1 -2], thresholds=[0.78379671        nan 0.68702206        nan        nan        nan
#          nan        nan], leaf_vals=[        nan -0.00844511         nan         nan         nan -0.01210381
#    0.03140124         nan], n_vals=[120  98  22  -2  -2  12  10  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.46689276        nan        nan        nan], leaf_vals=[        nan -0.01894285  0.00392891         nan], n_vals=[120  65  55  -2]),
#  Tree(vars=[ 1  0 -1 -1 -1 -2 -2 -2], thresholds=[0.58778035 0.46836           nan        nan        nan        nan
#          nan        nan], leaf_vals=[        nan         nan  0.02963351 -0.03413037 -0.01864785         nan
#           nan         nan], n_vals=[120  70  50  41  29  -2  -2  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.47723238        nan        nan        nan], leaf_vals=[        nan -0.07737513 -0.00448766         nan], n_vals=[120  55  65  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.11667251        nan        nan        nan], leaf_vals=[        nan -0.00611912  0.03795359         nan], n_vals=[120  16 104  -2]),
#  Tree(vars=[ 1  0 -1 -1 -1 -2 -2 -2], thresholds=[0.51999857 0.66923384        nan        nan        nan        nan
#          nan        nan], leaf_vals=[       nan        nan 0.06383236 0.04637294 0.01638225        nan
#          nan        nan], n_vals=[120  62  58  47  15  -2  -2  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.21091556        nan        nan        nan], leaf_vals=[       nan 0.01752521 0.03596576        nan], n_vals=[120  30  90  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.10270177        nan        nan        nan], leaf_vals=[        nan -0.028073    0.01291233         nan], n_vals=[120  12 108  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.17053312        nan        nan        nan], leaf_vals=[       nan 0.03295388 0.05914663        nan], n_vals=[120  25  95  -2]),
#  Tree(vars=[-1 -2], thresholds=[nan nan], leaf_vals=[-0.00715023         nan], n_vals=[120  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.774004      nan      nan      nan], leaf_vals=[        nan -0.00074803 -0.04747223         nan], n_vals=[120  95  25  -2]),
#  Tree(vars=[ 0  1  1 -1 -1 -1 -1 -2], thresholds=[0.29164034 0.42399362 0.89767213        nan        nan        nan
#          nan        nan], leaf_vals=[        nan         nan         nan -0.01458249  0.00623229 -0.00953784
#   -0.00867572         nan], n_vals=[120  40  80  16  24  76   4  -2]),
#  Tree(vars=[ 1  0 -1 -1 -1 -2 -2 -2], thresholds=[0.554559   0.09292644        nan        nan        nan        nan
#          nan        nan], leaf_vals=[        nan         nan -0.02695342  0.01697228 -0.04832025         nan
#           nan         nan], n_vals=[120  66  54   9  57  -2  -2  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.03697175        nan        nan        nan], leaf_vals=[        nan -0.01877942  0.03407388         nan], n_vals=[120   4 116  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.16558937        nan        nan        nan], leaf_vals=[        nan -0.02439253  0.02033518         nan], n_vals=[120  20 100  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.82881229        nan        nan        nan], leaf_vals=[        nan  0.02139239 -0.02173561         nan], n_vals=[120 100  20  -2]),
#  Tree(vars=[ 0 -1  0 -2 -2 -1 -1 -2], thresholds=[0.26331385        nan 0.28680396        nan        nan        nan
#          nan        nan], leaf_vals=[        nan -0.03188192         nan         nan         nan -0.04988073
#    0.00945265         nan], n_vals=[120  36  84  -2  -2   3  81  -2]),
#  Tree(vars=[ 1  1 -1 -1 -1 -2 -2 -2], thresholds=[0.42399362 0.05362162        nan        nan        nan        nan
#          nan        nan], leaf_vals=[       nan        nan 0.03727492 0.0084536  0.01232329        nan
#          nan        nan], n_vals=[120  49  71   8  41  -2  -2  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.77396337        nan        nan        nan], leaf_vals=[        nan  0.01387612 -0.03042972         nan], n_vals=[120  91  29  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.10781608        nan        nan        nan], leaf_vals=[        nan -0.00569715  0.02393107         nan], n_vals=[120  14 106  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.29510381        nan        nan        nan], leaf_vals=[        nan -0.02923386  0.04375133         nan], n_vals=[120  41  79  -2]),
#  Tree(vars=[ 1  0  0 -1 -1 -1 -1 -2], thresholds=[0.4623844  0.78379671 0.17053312        nan        nan        nan
#          nan        nan], leaf_vals=[        nan         nan         nan -0.05082034 -0.01981216 -0.03610337
#    0.0472172          nan], n_vals=[120  54  66  47   7  14  52  -2]),
#  Tree(vars=[ 0 -1  1 -2 -2  0 -1 -2 -2 -2 -2 -1 -1 -2 -2 -2], thresholds=[0.01393629        nan 0.57122029        nan        nan 0.29510381
#          nan        nan        nan        nan        nan        nan
#          nan        nan        nan        nan], leaf_vals=[        nan  0.01753474         nan         nan         nan         nan
#   -0.00211028         nan         nan         nan         nan -0.05505787
#    0.04194532         nan         nan         nan], n_vals=[120   1 119  -2  -2  67  52  -2  -2  -2  -2  23  44  -2  -2  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.26331385        nan        nan        nan], leaf_vals=[        nan -0.00613721  0.02342077         nan], n_vals=[120  36  84  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.03697175        nan        nan        nan], leaf_vals=[       nan 0.05746987 0.0080712         nan], n_vals=[120   4 116  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.59333154        nan        nan        nan], leaf_vals=[       nan 0.02223283 0.04062481        nan], n_vals=[120  77  43  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.70812683        nan        nan        nan], leaf_vals=[        nan -0.01620779  0.01522615         nan], n_vals=[120  85  35  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.29952342        nan        nan        nan], leaf_vals=[       nan 0.01418462 0.07125624        nan], n_vals=[120  42  78  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.79785885        nan        nan        nan], leaf_vals=[        nan -0.02241323  0.03271498         nan], n_vals=[120  96  24  -2]),
#  Tree(vars=[ 1  0 -1 -1 -1 -2 -2 -2], thresholds=[0.13700382 0.66923384        nan        nan        nan        nan
#          nan        nan], leaf_vals=[        nan         nan  0.02216972 -0.00135744  0.02431169         nan
#           nan         nan], n_vals=[120  16 104  13   3  -2  -2  -2]),
#  Tree(vars=[-1 -2], thresholds=[nan nan], leaf_vals=[-0.00451943         nan], n_vals=[120  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.19767083        nan        nan        nan], leaf_vals=[        nan -0.02919859  0.00312894         nan], n_vals=[120  28  92  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.4545228       nan       nan       nan], leaf_vals=[        nan -0.03857259  0.04623767         nan], n_vals=[120  53  67  -2]),
#  Tree(vars=[ 0  1 -1 -1 -1 -2 -2 -2], thresholds=[0.14958207 0.28083535        nan        nan        nan        nan
#          nan        nan], leaf_vals=[        nan         nan  0.04008849 -0.0257158  -0.00803124         nan
#           nan         nan], n_vals=[120  22  98   5  17  -2  -2  -2]),
#  Tree(vars=[ 1 -1  1 -2 -2 -1 -1 -2], thresholds=[0.27092509        nan 0.47723238        nan        nan        nan
#          nan        nan], leaf_vals=[        nan -0.01103195         nan         nan         nan -0.00355225
#    0.01628683         nan], n_vals=[120  30  90  -2  -2  25  65  -2]),
#  Tree(vars=[ 1  1 -1 -1 -1 -2 -2 -2], thresholds=[0.75361789 0.60854907        nan        nan        nan        nan
#          nan        nan], leaf_vals=[        nan         nan  0.04744192 -0.03680983 -0.00384703         nan
#           nan         nan], n_vals=[120  90  30  72  18  -2  -2  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.45335264        nan        nan        nan], leaf_vals=[       nan 0.00411435 0.0242028         nan], n_vals=[120  62  58  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.91158673        nan        nan        nan], leaf_vals=[       nan 0.00569228 0.0291232         nan], n_vals=[120 111   9  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.18031192        nan        nan        nan], leaf_vals=[        nan -0.01676062  0.0234776          nan], n_vals=[120  27  93  -2]),
#  Tree(vars=[ 0 -1 -1 -2], thresholds=[0.65128575        nan        nan        nan], leaf_vals=[        nan -0.02125325  0.01703286         nan], n_vals=[120  81  39  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.78460771        nan        nan        nan], leaf_vals=[        nan -0.01994735  0.01841462         nan], n_vals=[120  93  27  -2]),
#  Tree(vars=[ 1 -1 -1 -2], thresholds=[0.31136559        nan        nan        nan], leaf_vals=[        nan -0.05470435  0.02902073         nan], n_vals=[120  35  85  -2]),
#  Tree(vars=[ 1 -1  0 -2 -2 -1 -1 -2], thresholds=[0.04485528        nan 0.55914191        nan        nan        nan
#          nan        nan], leaf_vals=[        nan -0.00463059         nan         nan         nan  0.00726656
#    0.00952015         nan], n_vals=[120   6 114  -2  -2  70  44  -2])]
