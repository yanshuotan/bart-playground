# %%
from priors import BARTPrior
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from priors import BARTPrior
#
# File c:\Learning\Phd\BART\bartpy\bart-playground\src\priors.py:3
#       1 import numpy as np
# ----> 3 from params import TreeParams
#       5 class BARTPrior:
#       6     """
#       7     Represents the priors for the BART model.
#       8     """
#
# File c:\Learning\Phd\BART\bartpy\bart-playground\src\params.py:285
#     281         else:
#     282             return f"X_{self.vars[node_id]} <= {self.thresholds[node_id]:0.3f}" + \
#     283                 f" (split, n = {self.n_vals[node_id]})"
# --> 285 class BARTParams:
#     286     """
#     287     Represents the parameters of the BART model.
#     288     """
#     289     def __init__(self, trees: list, sigma2: float, prior: BARTPrior, X : np.ndarray, y : np.ndarray):
#
# ...
